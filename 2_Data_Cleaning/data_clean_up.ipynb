# %% [markdown]
# ## Data Clean Up
# Looking through the data collected from the spotify and genius api, it can be seen that there are several duplicate values for the tracks collected as well as repeating lyrics, which need to be resolved. Some lyrics are in spanish which need to be separated from the english lyrics in order to maintain an accurate representation for each language. There are several null values for the lyrics and several non-lyrics values retreived from the genius api which need to be removed.
#
# The spotify api did not return any genres for the songs which makes the genres column insignifigant to the analysis. However, looking at the artist data in the ArtistDetails.csv, the genres for the songs can be filled with the artist main genres to get a more inclusive analysis. In order to do that, it is important to track the unique genres and create an algorithm that finds  the main genre under which the artist would e categorized. For example, if an artist has 'soft pop' and 'canadian pop' for genres under their name then the main genre would be pop and so on.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import regex as re

# %%
df = pd.read_csv('/Users/mariamtamer/VSCodeProjects/lyricalanalysis copy/All_Songs.csv')

# %%
df.head()
# Out:
#                       song_artists                                   uri  \
# 0                        ['Drake']  spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1                        ['Drake']  spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2            ['Drake', 'Lil Baby']  spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3  ['Drake', 'Lil Durk', 'Giveon']  spotify:track:61S79KIVA4I9FXbnsylEHT
# 4               ['Drake', 'JAY-Z']  spotify:track:4VCbgIdr8ptegWeJpqLVHH
#
#                               track_name  duration_ms  explicit  \
# 0                       Champagne Poetry       336511      True
# 1                            Papi’s Home       178623      True
# 2       Girls Want Girls (with Lil Baby)       221979      True
# 3  In The Bible (with Lil Durk & Giveon)       296568      True
# 4                  Love All (with JAY-Z)       228461      True
#
#    track_popularity  track_number           album_name album_artist  \
# 0                82             1  Certified Lover Boy        Drake
# 1                76             2  Certified Lover Boy        Drake
# 2                86             3  Certified Lover Boy        Drake
# 3                79             4  Certified Lover Boy        Drake
# 4                77             5  Certified Lover Boy        Drake
#
#   album_release_date  ...  loudness mode  speechiness    tempo  \
# 0         2021-09-03  ...    -7.012  0.0        0.326   86.743
# 1         2021-09-03  ...    -6.157  1.0        0.313  140.177
# 2         2021-09-03  ...    -8.726  0.0        0.290   86.975
# 3         2021-09-03  ...    -8.350  0.0        0.297  143.070
# 4         2021-09-03  ...    -5.442  1.0        0.287   92.131
#
#    time_signature  valence                                        song_lyrics  \
# 0             4.0    0.496  Champagne Poetry Lyrics\n\nI love you, I love ...
# 1             4.0    0.588  Papi’s Home Lyrics\nI know that I hurt you\nYe...
# 2             4.0    0.381                                                NaN
# 3             4.0    0.147  In The Bible Lyrics\nOkay, okay, okay\nCountin...
# 4             4.0    0.155                                                NaN
#
#    lyrics_page_views     cleaned_title        featured_artists
# 0           688853.0  Champagne Poetry                     NaN
# 1           445883.0       Papi’s Home                     NaN
# 2                NaN               NaN                     NaN
# 3           439186.0      In The Bible  ['GIVĒON', 'Lil Durk']
# 4                NaN               NaN                     NaN
#
# [5 rows x 30 columns]

# %%
df.sample(10)
# Out:
#                                            song_artists  \
# 72174                                       ['Jeremih']
# 50972                   ['Gucci Mane', 'Figg Panamera']
# 103626                                     ['The Cure']
# 18998   ['Diplo', 'Deorro', 'Steve Aoki', 'Steve Bays']
# 108532                               ['The Beach Boys']
# 83723                                  ['Dire Straits']
# 157395                           ['Nat King Cole Trio']
# 57108                                    ['The Script']
# 65486                                     ['James Bay']
# 125420                                     ['Rod Wave']
#
#                                          uri  \
# 72174   spotify:track:49Rh91AUiqsv8DbZtYfeml
# 50972   spotify:track:7wergCwlxtxaFCVrESpWhV
# 103626  spotify:track:061LND8RZbg9PowQbf1uWp
# 18998   spotify:track:0GATmBanwPiHQBfl2mDq3o
# 108532  spotify:track:1hnTtn9CKhZdPIZHMJzYLc
# 83723   spotify:track:7LXxMApcyuh5A3sod0nV5s
# 157395  spotify:track:3XOPpTTVZXK6hAQeblDnRG
# 57108   spotify:track:2QWP8NYYplOqEFBYGCcq0S
# 65486   spotify:track:3ZQsCvbpp2HVXt9Mp46f8n
# 125420  spotify:track:0JjsAFEWLrv1b8nMFhQqhI
#
#                                                track_name  duration_ms  \
# 72174                                            773 Love       229856
# 50972                                     Spare Dat Bitch       138556
# 103626                                    The Walk - Live       208053
# 18998                            Freak (feat. Steve Bays)       281250
# 108532                                            Deirdre       209866
# 83723                                 You and Your Friend       359333
# 157395  (I Love You) For Sentimental Reasons - 2003 Re...       174760
# 57108                                                Rain       209346
# 65486                                           Let It Go       261533
# 125420                                   Ain't Mad At You       180733
#
#         explicit  track_popularity  track_number  \
# 72174      False                46             8
# 50972       True                 9            14
# 103626     False                37             5
# 18998      False                52             4
# 108532     False                40             5
# 83723      False                41             6
# 157395     False                13             5
# 57108       True                65             2
# 65486      False                29             3
# 125420      True                54            25
#
#                                                album_name    album_artist  \
# 72174                            Late Nights With Jeremih         Jeremih
# 50972                                      Fillmoelanta 3      Gucci Mane
# 103626  Anniversary: 1978 - 2018 Live In Hyde Park London        The Cure
# 18998                     Random White Dude Be Everywhere           Diplo
# 108532  "Feel Flows" The Sunflower & Surf’s Up Session...  The Beach Boys
# 83723                          On Every Street (Remaster)    Dire Straits
# 157395                         The World Of Nat King Cole   Nat King Cole
# 57108                                       Freedom Child      The Script
# 65486                                  Chaos And The Calm       James Bay
# 125420                               Pray 4 Love (Deluxe)        Rod Wave
#
#        album_release_date  ...  loudness mode  speechiness    tempo  \
# 72174          2022-03-11  ...    -4.672  0.0       0.3710   90.753
# 50972          2013-07-20  ...    -6.332  1.0       0.0510   97.014
# 103626         2019-10-18  ...    -5.983  1.0       0.1190  107.669
# 18998          2014-07-29  ...    -3.593  0.0       0.0483  150.045
# 108532         2021-08-27  ...    -8.478  1.0       0.1250  100.000
# 83723          1991-09-10  ...   -14.037  1.0       0.0530  113.818
# 157395         2005-01-01  ...    -8.626  1.0       0.0355  132.362
# 57108          2017-09-01  ...   -12.188  1.0       0.0387  197.569
# 65486          2015-03-25  ...   -18.446  1.0       0.0408  121.615
# 125420         2020-08-07  ...    -9.666  0.0       0.0589   89.984
#
#         time_signature  valence  \
# 72174              4.0   0.3170
# 50972              4.0   0.0657
# 103626             5.0   0.1330
# 18998              4.0   0.6240
# 108532             4.0   0.3090
# 83723              4.0   0.2220
# 157395             4.0   0.2220
# 57108              4.0   0.2200
# 65486              4.0   0.7270
# 125420             4.0   0.4970
#
#                                               song_lyrics  lyrics_page_views  \
# 72174   773 Love Lyrics\nEar Drummers\nHa, you know th...            46892.0
# 50972   Spare Dat Bitch LyricsHook:\nScandalous ass bi...                NaN
# 103626  The walk - live at the palace, auburn hills, m...                NaN
# 18998   Freak LyricsHey!\nHey!\nHey!\nHey!\nHey!\nHey!...            21309.0
# 108532  Deirdre Lyrics\nDeirdre\n\nThe trouble you had...             6451.0
# 83723   You and Your Friend Lyrics\n\nWill you and you...             6533.0
# 157395                                                NaN                NaN
# 57108                                                 NaN                NaN
# 65486   Let It Go Lyrics\nFrom walking home and talkin...           913814.0
# 125420  Ain’t Mad at You Lyrics\n(Trillo Beats, you di...            32800.0
#
#                                             cleaned_title  featured_artists
# 72174                                            773 Love               NaN
# 50972                                     Spare Dat Bitch               NaN
# 103626  The walk - live at the palace, auburn hills, m...               NaN
# 18998                                               Freak    ['Steve Bays']
# 108532                                            Deirdre               NaN
# 83723                                 You and Your Friend               NaN
# 157395                                                NaN               NaN
# 57108                                                 NaN               NaN
# 65486                                           Let It Go               NaN
# 125420                                   Ain’t Mad at You               NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# As seen above, the column names are not descriptive and inconsistant and can be rather confusing to work with, so it is necessary important to have column names that exactly tell the function of the column.
#
# Additionally, the column names can be reorganized in a more logical fashion to have the closely related attriutes following each other and enable viewing them side by side.

# %%
df.rename(columns = {'song_artists': 'track_artists', 'uri':'track_uri', 'duration_ms': 'track_duration_ms', 'explicit': 'track_is_explicit', 
'label': 'album_record_label', 'genres': 'album_genres', 'song_lyrics': 'track_lyrics', 'cleaned_title': 'cleaned_track_name', 
'acousticness': 'track_acousticness', 'danceability':'track_danceability', 'energy': 'track_energy', 'instrumentalness': 'track_instrumentalness', 
'key':'track_key', 'liveness': 'track_liveness' ,'loudness': 'track_loudness', 'mode': 'track_mode', 'speechiness': 'track_speechiness', 
'tempo': 'track_tempo', 'time_signature': 'track_time_signature', 'valence': 'track_valence'}, inplace = True)

# %%
column_names = ['track_uri', 'track_name', 'cleaned_track_name', 'track_artists', 'featured_artists', 'track_is_explicit', 'track_popularity', 'track_duration_ms', 'track_time_signature', 'track_acousticness', 
'track_danceability', 'track_energy', 'track_instrumentalness', 'track_key', 'track_liveness', 'track_loudness', 'track_mode', 'track_speechiness', 'track_tempo', 'track_valence', 
'track_lyrics', 'lyrics_page_views', 'track_number', 'album_name', 'album_artist', 'album_release_date', 'album_genres', 'album_popularity','album_record_label', 'album_cover']

df = df.reindex(columns=column_names)

# %%
df
# Out:
#                                    track_uri  \
# 0       spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1       spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2       spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3       spotify:track:61S79KIVA4I9FXbnsylEHT
# 4       spotify:track:4VCbgIdr8ptegWeJpqLVHH
# ...                                      ...
# 159226  spotify:track:0VxTtE5HoNMf9sp30j6c9V
# 159227  spotify:track:3EHx4H0FsTplZrcFSeuLeE
# 159228  spotify:track:4GfGx2zvY8pIwf2o2SAufU
# 159229  spotify:track:7dODnrD8danC9FD5xLb9Tu
# 159230  spotify:track:76F74qIRn19FmIdl6mMQAP
#
#                                    track_name             cleaned_track_name  \
# 0                            Champagne Poetry               Champagne Poetry
# 1                                 Papi’s Home                    Papi’s Home
# 2            Girls Want Girls (with Lil Baby)                            NaN
# 3       In The Bible (with Lil Durk & Giveon)                   In The Bible
# 4                       Love All (with JAY-Z)                            NaN
# ...                                       ...                            ...
# 159226                              Try Again                            NaN
# 159227              What I Want Is What I Got   What I Want Is What I’ve Got
# 159228                             We Are One                            NaN
# 159229          Can't Lose What You Never Had  Can’t Lose What You Never Had
# 159230                       My Private Movie               My Private Movie
#
#                           track_artists        featured_artists  \
# 0                             ['Drake']                     NaN
# 1                             ['Drake']                     NaN
# 2                 ['Drake', 'Lil Baby']                     NaN
# 3       ['Drake', 'Lil Durk', 'Giveon']  ['GIVĒON', 'Lil Durk']
# 4                    ['Drake', 'JAY-Z']                     NaN
# ...                                 ...                     ...
# 159226                     ['Westlife']                     NaN
# 159227                     ['Westlife']                     NaN
# 159228                     ['Westlife']                     NaN
# 159229                     ['Westlife']                     NaN
# 159230                     ['Westlife']                     NaN
#
#         track_is_explicit  track_popularity  track_duration_ms  \
# 0                    True                82             336511
# 1                    True                76             178623
# 2                    True                86             221979
# 3                    True                79             296568
# 4                    True                77             228461
# ...                   ...               ...                ...
# 159226              False                47             214866
# 159227              False                46             213066
# 159228              False                45             222893
# 159229              False                45             264485
# 159230              False                37             244733
#
#         track_time_signature  track_acousticness  ...  \
# 0                        4.0            0.758000  ...
# 1                        4.0            0.112000  ...
# 2                        4.0            0.181000  ...
# 3                        4.0            0.614000  ...
# 4                        4.0            0.354000  ...
# ...                      ...                 ...  ...
# 159226                   3.0            0.000067  ...
# 159227                   4.0            0.000084  ...
# 159228                   4.0            0.012300  ...
# 159229                   4.0            0.009850  ...
# 159230                   3.0            0.000239  ...
#
#                                              track_lyrics  lyrics_page_views  \
# 0       Champagne Poetry Lyrics\n\nI love you, I love ...           688853.0
# 1       Papi’s Home Lyrics\nI know that I hurt you\nYe...           445883.0
# 2                                                     NaN                NaN
# 3       In The Bible Lyrics\nOkay, okay, okay\nCountin...           439186.0
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 159226                                                NaN                NaN
# 159227  What I Want Is What I’ve Got Lyrics\nAll that ...                NaN
# 159228                                                NaN                NaN
# 159229  Can’t Lose What You Never Had Lyrics\nBaby you...             6644.0
# 159230  My Private Movie LyricsPretty girls are all ar...                NaN
#
#         track_number           album_name  album_artist  album_release_date  \
# 0                  1  Certified Lover Boy         Drake          2021-09-03
# 1                  2  Certified Lover Boy         Drake          2021-09-03
# 2                  3  Certified Lover Boy         Drake          2021-09-03
# 3                  4  Certified Lover Boy         Drake          2021-09-03
# 4                  5  Certified Lover Boy         Drake          2021-09-03
# ...              ...                  ...           ...                 ...
# 159226            14             Westlife      Westlife          1999-11-01
# 159227            15             Westlife      Westlife          1999-11-01
# 159228            16             Westlife      Westlife          1999-11-01
# 159229            17             Westlife      Westlife          1999-11-01
# 159230            18             Westlife      Westlife          1999-11-01
#
#         album_genres  album_popularity  album_record_label  \
# 0                NaN                95                 OVO
# 1                NaN                95                 OVO
# 2                NaN                95                 OVO
# 3                NaN                95                 OVO
# 4                NaN                95                 OVO
# ...              ...               ...                 ...
# 159226           NaN                73   RCA Records Label
# 159227           NaN                73   RCA Records Label
# 159228           NaN                73   RCA Records Label
# 159229           NaN                73   RCA Records Label
# 159230           NaN                73   RCA Records Label
#
#                                               album_cover
# 0       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 1       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 2       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 3       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 4       https://i.scdn.co/image/ab67616d00001e02cd945b...
# ...                                                   ...
# 159226  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159227  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159228  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159229  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159230  https://i.scdn.co/image/ab67616d00001e0244ead2...
#
# [159231 rows x 30 columns]

# %%
# Let's see df's dimensionality with df.shape

df.shape
# Out:
# (159231, 30)

# %%
# To find how many unique values columns have

df.nunique()
# Out:
# track_uri                 156480
# track_name                105118
# cleaned_track_name         57046
# track_artists              17885
# featured_artists            5782
# track_is_explicit              2
# track_popularity              98
# track_duration_ms          53780
# track_time_signature           5
# track_acousticness          4155
# track_danceability          1151
# track_energy                1898
# track_instrumentalness      5290
# track_key                     12
# track_liveness              1668
# track_loudness             18448
# track_mode                     2
# track_speechiness           1594
# track_tempo                44084
# track_valence               1650
# track_lyrics               57965
# lyrics_page_views          26616
# track_number                  50
# album_name                  9574
# album_artist                 797
# album_release_date          3772
# album_genres                   0
# album_popularity             100
# album_record_label          1448
# album_cover                 9752
# dtype: int64

# %%
describ = df.describe() # assign describe to variable
null_sum = pd.concat([df.isnull().sum().rename('NullData'),describ.T],axis=1)

# %%
null_sum
# Out:
#                     NullData     count           mean            std     min  \
# song_artists               0       NaN            NaN            NaN     NaN
# uri                        0       NaN            NaN            NaN     NaN
# track_name                 0       NaN            NaN            NaN     NaN
# duration_ms                0  159231.0  226734.568445  109223.122570  3338.0
# explicit                   0       NaN            NaN            NaN     NaN
# track_popularity           0  159231.0      30.132688      19.650210     0.0
# track_number               0  159231.0       8.916128       6.524022     1.0
# album_name                 0       NaN            NaN            NaN     NaN
# album_artist               0       NaN            NaN            NaN     NaN
# album_release_date         0       NaN            NaN            NaN     NaN
# genres                159231       0.0            NaN            NaN     NaN
# label                      0       NaN            NaN            NaN     NaN
# album_popularity           0  159231.0      47.024763      20.997290     0.0
# album_cover               41       NaN            NaN            NaN     NaN
# acousticness              48  159183.0       0.318934       0.318564     0.0
# danceability              48  159183.0       0.566812       0.178980     0.0
# energy                    48  159183.0       0.599635       0.236088     0.0
# instrumentalness          48  159183.0       0.080285       0.230314     0.0
# key                       48  159183.0       5.206492       3.573586     0.0
# liveness                  48  159183.0       0.256745       0.245704     0.0
# loudness                  48  159183.0      -8.462706       4.572328   -60.0
# mode                      48  159183.0       0.657357       0.474595     0.0
# speechiness               48  159183.0       0.114471       0.143858     0.0
# tempo                     48  159183.0     120.008114      30.345771     0.0
# time_signature            48  159183.0       3.900932       0.448415     0.0
# valence                   48  159183.0       0.474591       0.246683     0.0
# song_lyrics            73160       NaN            NaN            NaN     NaN
# lyrics_page_views     113530   45701.0  174480.623838  541857.683513  5001.0
# cleaned_title          67860       NaN            NaN            NaN     NaN
# featured_artists      144057       NaN            NaN            NaN     NaN
#
#                             25%            50%           75%           max
# song_artists                NaN            NaN           NaN           NaN
# uri                         NaN            NaN           NaN           NaN
# track_name                  NaN            NaN           NaN           NaN
# duration_ms         177263.0000  214515.000000  259120.00000  4.794398e+06
# explicit                    NaN            NaN           NaN           NaN
# track_popularity        14.0000      29.000000      44.00000  9.700000e+01
# track_number             4.0000       8.000000      12.00000  5.000000e+01
# album_name                  NaN            NaN           NaN           NaN
# album_artist                NaN            NaN           NaN           NaN
# album_release_date          NaN            NaN           NaN           NaN
# genres                      NaN            NaN           NaN           NaN
# label                       NaN            NaN           NaN           NaN
# album_popularity        32.0000      49.000000      63.00000  1.000000e+02
# album_cover                 NaN            NaN           NaN           NaN
# acousticness             0.0377       0.192000       0.57800  9.960000e-01
# danceability             0.4480       0.582000       0.70100  9.800000e-01
# energy                   0.4420       0.631000       0.78700  1.000000e+00
# instrumentalness         0.0000       0.000003       0.00118  1.000000e+00
# key                      2.0000       5.000000       8.00000  1.100000e+01
# liveness                 0.1010       0.143000       0.31700  1.000000e+00
# loudness               -10.2215      -7.278000      -5.40500  9.320000e-01
# mode                     0.0000       1.000000       1.00000  1.000000e+00
# speechiness              0.0363       0.052600       0.12400  9.660000e-01
# tempo                   95.3085     119.984000     139.94900  2.410050e+02
# time_signature           4.0000       4.000000       4.00000  5.000000e+00
# valence                  0.2790       0.466000       0.66300  1.000000e+00
# song_lyrics                 NaN            NaN           NaN           NaN
# lyrics_page_views    13948.0000   38911.000000  132169.00000  2.335146e+07
# cleaned_title               NaN            NaN           NaN           NaN
# featured_artists            NaN            NaN           NaN           NaN
