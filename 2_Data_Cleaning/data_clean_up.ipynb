# %% [markdown]
# ## Data Clean Up
# Looking through the data collected from the spotify and genius api, it can be seen that there are several duplicate values for the tracks collected as well as repeating lyrics, which need to be resolved. Some lyrics are in spanish which need to be separated from the english lyrics in order to maintain an accurate representation for each language. There are several null values for the lyrics and several non-lyrics values retreived from the genius api which need to be removed.
#
# The spotify api did not return any genres for the songs which makes the genres column insignifigant to the analysis. However, looking at the artist data in the ArtistDetails.csv, the genres for the songs can be filled with the artist main genres to get a more inclusive analysis. In order to do that, it is important to track the unique genres and create an algorithm that finds  the main genre under which the artist would e categorized. For example, if an artist has 'soft pop' and 'canadian pop' for genres under their name then the main genre would be pop and so on.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import regex as re

# %% [markdown]
# First the csv containing the data is read and samples are taken in order to identify the distriution and attributes of the data collected

# %%
df = pd.read_csv('/Users/mariamtamer/VSCodeProjects/lyricalanalysis copy/All_Songs.csv')

# %%
df.head()
# Out:
#                       song_artists                                   uri  \
# 0                        ['Drake']  spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1                        ['Drake']  spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2            ['Drake', 'Lil Baby']  spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3  ['Drake', 'Lil Durk', 'Giveon']  spotify:track:61S79KIVA4I9FXbnsylEHT
# 4               ['Drake', 'JAY-Z']  spotify:track:4VCbgIdr8ptegWeJpqLVHH
#
#                               track_name  duration_ms  explicit  \
# 0                       Champagne Poetry       336511      True
# 1                            Papi’s Home       178623      True
# 2       Girls Want Girls (with Lil Baby)       221979      True
# 3  In The Bible (with Lil Durk & Giveon)       296568      True
# 4                  Love All (with JAY-Z)       228461      True
#
#    track_popularity  track_number           album_name album_artist  \
# 0                82             1  Certified Lover Boy        Drake
# 1                76             2  Certified Lover Boy        Drake
# 2                86             3  Certified Lover Boy        Drake
# 3                79             4  Certified Lover Boy        Drake
# 4                77             5  Certified Lover Boy        Drake
#
#   album_release_date  ...  loudness mode  speechiness    tempo  \
# 0         2021-09-03  ...    -7.012  0.0        0.326   86.743
# 1         2021-09-03  ...    -6.157  1.0        0.313  140.177
# 2         2021-09-03  ...    -8.726  0.0        0.290   86.975
# 3         2021-09-03  ...    -8.350  0.0        0.297  143.070
# 4         2021-09-03  ...    -5.442  1.0        0.287   92.131
#
#    time_signature  valence                                        song_lyrics  \
# 0             4.0    0.496  Champagne Poetry Lyrics\n\nI love you, I love ...
# 1             4.0    0.588  Papi’s Home Lyrics\nI know that I hurt you\nYe...
# 2             4.0    0.381                                                NaN
# 3             4.0    0.147  In The Bible Lyrics\nOkay, okay, okay\nCountin...
# 4             4.0    0.155                                                NaN
#
#    lyrics_page_views     cleaned_title        featured_artists
# 0           688853.0  Champagne Poetry                     NaN
# 1           445883.0       Papi’s Home                     NaN
# 2                NaN               NaN                     NaN
# 3           439186.0      In The Bible  ['GIVĒON', 'Lil Durk']
# 4                NaN               NaN                     NaN
#
# [5 rows x 30 columns]

# %%
df.sample(10)
# Out:
#                                   song_artists  \
# 14072                          ['Demi Lovato']
# 77069                       ['Alejandro Sanz']
# 155101  ['Ella Fitzgerald', 'Louis Armstrong']
# 39479           ['French Montana', 'Alkaline']
# 92707                        ['Blake Shelton']
# 132677                           ['Scorpions']
# 60140                    ['Bruce Springsteen']
# 23142                                ['Gunna']
# 152318                         ['Dean Martin']
# 31981                   ['The Rolling Stones']
#
#                                          uri  \
# 14072   spotify:track:6zBQ1w06kbswixA2LvnFIv
# 77069   spotify:track:5Vf0C2h6SgNO2WbWm6TNNh
# 155101  spotify:track:24jvRTDOvNENB2umZlBEIf
# 39479   spotify:track:6VYHQu2gmnyrQhBcI3NzxY
# 92707   spotify:track:5kFN8BG2qO933G3gFxVvYv
# 132677  spotify:track:2Q8bBl1ZBQW61cdOuU7ZKb
# 60140   spotify:track:6iqlxdQjvNlAuUrHCgMau8
# 23142   spotify:track:5bWYPkdp7tPbp1dhE9AX43
# 152318  spotify:track:3Y2jaEYu4R9ECTjL2D260H
# 31981   spotify:track:3omdSLoDVN74I8mqOzHHDx
#
#                                                track_name  duration_ms  \
# 14072                                           Butterfly       157252
# 77069                                           Amiga mía       304013
# 155101                                     A Fine Romance       235973
# 39479                                             Formula       234274
# 92707                                   I Can't Walk Away       221386
# 132677                                            Lorelei       272906
# 60140   It's Hard To Be A Saint In The City - Live at ...       327773
# 23142                                            Yao Ming       149613
# 152318                                    Brahms' Lullaby       180400
# 31981         She's A Rainbow - Full Version / With Intro       275160
#
#         explicit  track_popularity  track_number  \
# 14072      False                44            18
# 77069      False                50             3
# 155101     False                28            10
# 39479       True                37            15
# 92707      False                10            13
# 132677     False                 2             7
# 60140      False                27             8
# 23142       True                55             6
# 152318     False                21            12
# 31981      False                25             6
#
#                                              album_name        album_artist  \
# 14072   Dancing With The Devil…The Art of Starting Over         Demi Lovato
# 77069                                     MTV Unplugged      Alejandro Sanz
# 155101             The Complete Ella And Louis On Verve     Ella Fitzgerald
# 39479                                      Jungle Rules      French Montana
# 92707                          Pure BS (Deluxe Edition)       Blake Shelton
# 132677                                Sting In The Tail           Scorpions
# 60140                     Hammersmith Odeon, London '75   Bruce Springsteen
# 23142                                   Drip or Drown 2               Gunna
# 152318                                       Sleep Warm         Dean Martin
# 31981                   Their Satanic Majesties Request  The Rolling Stones
#
#        album_release_date  ...  loudness mode  speechiness    tempo  \
# 14072          2021-04-02  ...    -5.229  1.0       0.0362  139.853
# 77069          2001-11-19  ...    -8.952  0.0       0.0311  180.343
# 155101         1997-05-20  ...   -14.110  0.0       0.1600  173.733
# 39479          2017-07-14  ...   -23.435  0.0       0.3300  124.603
# 92707          2007-05-01  ...    -7.997  1.0       0.0309  137.960
# 132677         2010-08-30  ...    -5.676  0.0       0.0826  165.638
# 60140          2006-02-28  ...    -6.028  1.0       0.3400  158.569
# 23142          2019-02-22  ...    -5.103  1.0       0.0742  169.751
# 152318               1959  ...    -6.536  1.0       0.0900  116.123
# 31981          1967-12-08  ...    -9.135  1.0       0.0420  109.143
#
#         time_signature  valence  \
# 14072              4.0    0.469
# 77069              3.0    0.128
# 155101             3.0    0.707
# 39479              4.0    0.664
# 92707              4.0    0.129
# 132677             4.0    0.417
# 60140              4.0    0.407
# 23142              4.0    0.308
# 152318             4.0    0.164
# 31981              4.0    0.533
#
#                                               song_lyrics  lyrics_page_views  \
# 14072                                                 NaN                NaN
# 77069   Amiga Mía Lyrics\nAmiga mía, lo sé, solo vives...             9838.0
# 155101  A Fine Romance LyricsA fine romance, with no k...             6240.0
# 39479   Formula Lyrics\nYes!\nEverything spicy, eeh?!\...            11188.0
# 92707   I Can’t Walk Away Lyrics\nThis morning when I ...                NaN
# 132677  Lorelei Lyrics\nThere was a time when we saile...             6556.0
# 60140                                                 NaN                NaN
# 23142   Yao Ming Lyrics\nYeah, yeah\nYeah, uh\n\nYao M...            52445.0
# 152318  Brahm’s Lullaby LyricsLullaby and good night\n...                NaN
# 31981                                                 NaN                NaN
#
#             cleaned_title  featured_artists
# 14072                 NaN               NaN
# 77069           Amiga Mía               NaN
# 155101     A Fine Romance               NaN
# 39479             Formula      ['Alkaline']
# 92707   I Can’t Walk Away               NaN
# 132677            Lorelei               NaN
# 60140                 NaN               NaN
# 23142            Yao Ming               NaN
# 152318    Brahm’s Lullaby               NaN
# 31981                 NaN               NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Clean Up
# As seen above, the column names are not descriptive and inconsistant and can be rather confusing to work with, so it is necessary to have column names that exactly tell the function of the column.
#
# Additionally, the column names can be reorganized in a more logical fashion to have the closely related attributes following each other and enable viewing them side by side.

# %% [markdown]
# #### Cleaning Column Names

# %%
df.rename(columns = {'song_artists': 'track_artists', 'uri':'track_uri', 'duration_ms': 'track_duration_ms', 'explicit': 'track_is_explicit', 
'label': 'album_record_label', 'genres': 'track_genres', 'song_lyrics': 'track_lyrics', 'cleaned_title': 'cleaned_track_name', 
'acousticness': 'track_acousticness', 'danceability':'track_danceability', 'energy': 'track_energy', 'instrumentalness': 'track_instrumentalness', 
'key':'track_key', 'liveness': 'track_liveness' ,'loudness': 'track_loudness', 'mode': 'track_mode', 'speechiness': 'track_speechiness', 
'tempo': 'track_tempo', 'time_signature': 'track_time_signature', 'valence': 'track_valence'}, inplace = True)

# %%
column_names = ['track_uri', 'track_name', 'cleaned_track_name', 'track_artists', 'featured_artists', 'track_is_explicit', 'track_popularity', 'track_genres', 'track_duration_ms', 'track_time_signature', 'track_acousticness', 
'track_danceability', 'track_energy', 'track_instrumentalness', 'track_key', 'track_mode', 'track_liveness', 'track_loudness', 'track_speechiness', 'track_tempo', 'track_valence', 
'track_lyrics', 'lyrics_page_views', 'track_number', 'album_name', 'album_artist', 'album_release_date', 'album_popularity','album_record_label', 'album_cover']

df = df.reindex(columns=column_names)

# %%
df
# Out:
#                                    track_uri  \
# 0       spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1       spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2       spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3       spotify:track:61S79KIVA4I9FXbnsylEHT
# 4       spotify:track:4VCbgIdr8ptegWeJpqLVHH
# ...                                      ...
# 159226  spotify:track:0VxTtE5HoNMf9sp30j6c9V
# 159227  spotify:track:3EHx4H0FsTplZrcFSeuLeE
# 159228  spotify:track:4GfGx2zvY8pIwf2o2SAufU
# 159229  spotify:track:7dODnrD8danC9FD5xLb9Tu
# 159230  spotify:track:76F74qIRn19FmIdl6mMQAP
#
#                                    track_name             cleaned_track_name  \
# 0                            Champagne Poetry               Champagne Poetry
# 1                                 Papi’s Home                    Papi’s Home
# 2            Girls Want Girls (with Lil Baby)                            NaN
# 3       In The Bible (with Lil Durk & Giveon)                   In The Bible
# 4                       Love All (with JAY-Z)                            NaN
# ...                                       ...                            ...
# 159226                              Try Again                            NaN
# 159227              What I Want Is What I Got   What I Want Is What I’ve Got
# 159228                             We Are One                            NaN
# 159229          Can't Lose What You Never Had  Can’t Lose What You Never Had
# 159230                       My Private Movie               My Private Movie
#
#                           track_artists        featured_artists  \
# 0                             ['Drake']                     NaN
# 1                             ['Drake']                     NaN
# 2                 ['Drake', 'Lil Baby']                     NaN
# 3       ['Drake', 'Lil Durk', 'Giveon']  ['GIVĒON', 'Lil Durk']
# 4                    ['Drake', 'JAY-Z']                     NaN
# ...                                 ...                     ...
# 159226                     ['Westlife']                     NaN
# 159227                     ['Westlife']                     NaN
# 159228                     ['Westlife']                     NaN
# 159229                     ['Westlife']                     NaN
# 159230                     ['Westlife']                     NaN
#
#         track_is_explicit  track_popularity  track_genres  track_duration_ms  \
# 0                    True                82           NaN             336511
# 1                    True                76           NaN             178623
# 2                    True                86           NaN             221979
# 3                    True                79           NaN             296568
# 4                    True                77           NaN             228461
# ...                   ...               ...           ...                ...
# 159226              False                47           NaN             214866
# 159227              False                46           NaN             213066
# 159228              False                45           NaN             222893
# 159229              False                45           NaN             264485
# 159230              False                37           NaN             244733
#
#         track_time_signature  ...  track_valence  \
# 0                        4.0  ...          0.496
# 1                        4.0  ...          0.588
# 2                        4.0  ...          0.381
# 3                        4.0  ...          0.147
# 4                        4.0  ...          0.155
# ...                      ...  ...            ...
# 159226                   3.0  ...          0.381
# 159227                   4.0  ...          0.744
# 159228                   4.0  ...          0.426
# 159229                   4.0  ...          0.656
# 159230                   3.0  ...          0.265
#
#                                              track_lyrics  lyrics_page_views  \
# 0       Champagne Poetry Lyrics\n\nI love you, I love ...           688853.0
# 1       Papi’s Home Lyrics\nI know that I hurt you\nYe...           445883.0
# 2                                                     NaN                NaN
# 3       In The Bible Lyrics\nOkay, okay, okay\nCountin...           439186.0
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 159226                                                NaN                NaN
# 159227  What I Want Is What I’ve Got Lyrics\nAll that ...                NaN
# 159228                                                NaN                NaN
# 159229  Can’t Lose What You Never Had Lyrics\nBaby you...             6644.0
# 159230  My Private Movie LyricsPretty girls are all ar...                NaN
#
#         track_number           album_name  album_artist  album_release_date  \
# 0                  1  Certified Lover Boy         Drake          2021-09-03
# 1                  2  Certified Lover Boy         Drake          2021-09-03
# 2                  3  Certified Lover Boy         Drake          2021-09-03
# 3                  4  Certified Lover Boy         Drake          2021-09-03
# 4                  5  Certified Lover Boy         Drake          2021-09-03
# ...              ...                  ...           ...                 ...
# 159226            14             Westlife      Westlife          1999-11-01
# 159227            15             Westlife      Westlife          1999-11-01
# 159228            16             Westlife      Westlife          1999-11-01
# 159229            17             Westlife      Westlife          1999-11-01
# 159230            18             Westlife      Westlife          1999-11-01
#
#         album_popularity  album_record_label  \
# 0                     95                 OVO
# 1                     95                 OVO
# 2                     95                 OVO
# 3                     95                 OVO
# 4                     95                 OVO
# ...                  ...                 ...
# 159226                73   RCA Records Label
# 159227                73   RCA Records Label
# 159228                73   RCA Records Label
# 159229                73   RCA Records Label
# 159230                73   RCA Records Label
#
#                                               album_cover
# 0       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 1       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 2       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 3       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 4       https://i.scdn.co/image/ab67616d00001e02cd945b...
# ...                                                   ...
# 159226  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159227  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159228  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159229  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159230  https://i.scdn.co/image/ab67616d00001e0244ead2...
#
# [159231 rows x 30 columns]

# %%
# Let's see df's dimensionality with df.shape

df.shape
# Out:
# (159231, 30)

# %% [markdown]
# #### Defining the Key Signature Column
# According to the spotify API and some background knowledge in music, the key signature of the song is represented using integer values available in two columns: Key and Mode. The combination of the key and the mode can be mapped to more commonly known key signatures which can give a more meaningful description to the data collected. Therefore, two dictionaries one for when the mode is 1 (major key) and another for when the mode is 0 (minor key). The dictionaries map the key to their full key signature. This will be used to create an extra column holding the key signature of the each track.

# %%
mode_1 = {0: 'C Major', 1: 'D♭ Major', 2: 'D Major', 3: 'E♭ Major', 4: 'E Major', 5: 'F Major', 6: 'F# Major', 7: 'G Major', 8: 'A♭ Major', 9: 'A Major', 10: 'B♭ Major', 11: 'B Major'}
mode_0 = {0: 'C Minor', 1: 'C# Minor', 2: 'D Minor', 3: 'D# Minor', 4: 'E Minor', 5: 'F Minor', 6: 'F# Minor', 7: 'G Minor', 8: 'G# Minor', 9: 'A Minor', 10: 'B♭ Minor', 11: 'B Minor'}

# %%
def get_key_signature(mode, key):
    if (mode == 1):
        key_signature = mode_1.get(key)
    elif (mode == 0):
        key_signature = mode_0.get(key)
    else:
        key_signature = None
    return key_signature

# %%
key_signature = df.apply(lambda x: get_key_signature(x.track_mode, x.track_key), axis= 1)
df.insert(13, 'track_key_signature', key_signature)
df
# Out:
#                                    track_uri  \
# 0       spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1       spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2       spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3       spotify:track:61S79KIVA4I9FXbnsylEHT
# 4       spotify:track:4VCbgIdr8ptegWeJpqLVHH
# ...                                      ...
# 159226  spotify:track:0VxTtE5HoNMf9sp30j6c9V
# 159227  spotify:track:3EHx4H0FsTplZrcFSeuLeE
# 159228  spotify:track:4GfGx2zvY8pIwf2o2SAufU
# 159229  spotify:track:7dODnrD8danC9FD5xLb9Tu
# 159230  spotify:track:76F74qIRn19FmIdl6mMQAP
#
#                                    track_name             cleaned_track_name  \
# 0                            Champagne Poetry               Champagne Poetry
# 1                                 Papi’s Home                    Papi’s Home
# 2            Girls Want Girls (with Lil Baby)                            NaN
# 3       In The Bible (with Lil Durk & Giveon)                   In The Bible
# 4                       Love All (with JAY-Z)                            NaN
# ...                                       ...                            ...
# 159226                              Try Again                            NaN
# 159227              What I Want Is What I Got   What I Want Is What I’ve Got
# 159228                             We Are One                            NaN
# 159229          Can't Lose What You Never Had  Can’t Lose What You Never Had
# 159230                       My Private Movie               My Private Movie
#
#                           track_artists        featured_artists  \
# 0                             ['Drake']                     NaN
# 1                             ['Drake']                     NaN
# 2                 ['Drake', 'Lil Baby']                     NaN
# 3       ['Drake', 'Lil Durk', 'Giveon']  ['GIVĒON', 'Lil Durk']
# 4                    ['Drake', 'JAY-Z']                     NaN
# ...                                 ...                     ...
# 159226                     ['Westlife']                     NaN
# 159227                     ['Westlife']                     NaN
# 159228                     ['Westlife']                     NaN
# 159229                     ['Westlife']                     NaN
# 159230                     ['Westlife']                     NaN
#
#         track_is_explicit  track_popularity  track_genres  track_duration_ms  \
# 0                    True                82           NaN             336511
# 1                    True                76           NaN             178623
# 2                    True                86           NaN             221979
# 3                    True                79           NaN             296568
# 4                    True                77           NaN             228461
# ...                   ...               ...           ...                ...
# 159226              False                47           NaN             214866
# 159227              False                46           NaN             213066
# 159228              False                45           NaN             222893
# 159229              False                45           NaN             264485
# 159230              False                37           NaN             244733
#
#         track_time_signature  ...  track_valence  \
# 0                        4.0  ...          0.496
# 1                        4.0  ...          0.588
# 2                        4.0  ...          0.381
# 3                        4.0  ...          0.147
# 4                        4.0  ...          0.155
# ...                      ...  ...            ...
# 159226                   3.0  ...          0.381
# 159227                   4.0  ...          0.744
# 159228                   4.0  ...          0.426
# 159229                   4.0  ...          0.656
# 159230                   3.0  ...          0.265
#
#                                              track_lyrics  lyrics_page_views  \
# 0       Champagne Poetry Lyrics\n\nI love you, I love ...           688853.0
# 1       Papi’s Home Lyrics\nI know that I hurt you\nYe...           445883.0
# 2                                                     NaN                NaN
# 3       In The Bible Lyrics\nOkay, okay, okay\nCountin...           439186.0
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 159226                                                NaN                NaN
# 159227  What I Want Is What I’ve Got Lyrics\nAll that ...                NaN
# 159228                                                NaN                NaN
# 159229  Can’t Lose What You Never Had Lyrics\nBaby you...             6644.0
# 159230  My Private Movie LyricsPretty girls are all ar...                NaN
#
#        track_number           album_name  album_artist  album_release_date  \
# 0                 1  Certified Lover Boy         Drake          2021-09-03
# 1                 2  Certified Lover Boy         Drake          2021-09-03
# 2                 3  Certified Lover Boy         Drake          2021-09-03
# 3                 4  Certified Lover Boy         Drake          2021-09-03
# 4                 5  Certified Lover Boy         Drake          2021-09-03
# ...             ...                  ...           ...                 ...
# 159226           14             Westlife      Westlife          1999-11-01
# 159227           15             Westlife      Westlife          1999-11-01
# 159228           16             Westlife      Westlife          1999-11-01
# 159229           17             Westlife      Westlife          1999-11-01
# 159230           18             Westlife      Westlife          1999-11-01
#
#         album_popularity  album_record_label  \
# 0                     95                 OVO
# 1                     95                 OVO
# 2                     95                 OVO
# 3                     95                 OVO
# 4                     95                 OVO
# ...                  ...                 ...
# 159226                73   RCA Records Label
# 159227                73   RCA Records Label
# 159228                73   RCA Records Label
# 159229                73   RCA Records Label
# 159230                73   RCA Records Label
#
#                                               album_cover
# 0       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 1       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 2       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 3       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 4       https://i.scdn.co/image/ab67616d00001e02cd945b...
# ...                                                   ...
# 159226  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159227  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159228  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159229  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159230  https://i.scdn.co/image/ab67616d00001e0244ead2...
#
# [159231 rows x 31 columns]

# %%
# To find how many unique values columns have

df.nunique()
# Out:
# track_uri                 156480
# track_name                105118
# cleaned_track_name         57046
# track_artists              17885
# featured_artists            5782
# track_is_explicit              2
# track_popularity              98
# track_genres                   0
# track_duration_ms          53780
# track_time_signature           5
# track_acousticness          4155
# track_danceability          1151
# track_energy                1898
# track_key_signature           24
# track_instrumentalness      5290
# track_key                     12
# track_mode                     2
# track_liveness              1668
# track_loudness             18448
# track_speechiness           1594
# track_tempo                44084
# track_valence               1650
# track_lyrics               57965
# lyrics_page_views          26616
# track_number                  50
# album_name                  9574
# album_artist                 797
# album_release_date          3772
# album_popularity             100
# album_record_label          1448
# album_cover                 9752
# dtype: int64

# %%
describ = df.describe() # assign describe to variable
null_sum = pd.concat([df.isnull().sum().rename('NullData'),describ.T],axis=1)

# %%
null_sum
# Out:
#                         NullData     count           mean            std  \
# track_uri                      0       NaN            NaN            NaN
# track_name                     0       NaN            NaN            NaN
# cleaned_track_name         67860       NaN            NaN            NaN
# track_artists                  0       NaN            NaN            NaN
# featured_artists          144057       NaN            NaN            NaN
# track_is_explicit              0       NaN            NaN            NaN
# track_popularity               0  159231.0      30.132688      19.650210
# track_genres              159231       0.0            NaN            NaN
# track_duration_ms              0  159231.0  226734.568445  109223.122570
# track_time_signature          48  159183.0       3.900932       0.448415
# track_acousticness            48  159183.0       0.318934       0.318564
# track_danceability            48  159183.0       0.566812       0.178980
# track_energy                  48  159183.0       0.599635       0.236088
# track_key_signature           48       NaN            NaN            NaN
# track_instrumentalness        48  159183.0       0.080285       0.230314
# track_key                     48  159183.0       5.206492       3.573586
# track_mode                    48  159183.0       0.657357       0.474595
# track_liveness                48  159183.0       0.256745       0.245704
# track_loudness                48  159183.0      -8.462706       4.572328
# track_speechiness             48  159183.0       0.114471       0.143858
# track_tempo                   48  159183.0     120.008114      30.345771
# track_valence                 48  159183.0       0.474591       0.246683
# track_lyrics               73160       NaN            NaN            NaN
# lyrics_page_views         113530   45701.0  174480.623838  541857.683513
# track_number                   0  159231.0       8.916128       6.524022
# album_name                     0       NaN            NaN            NaN
# album_artist                   0       NaN            NaN            NaN
# album_release_date             0       NaN            NaN            NaN
# album_popularity               0  159231.0      47.024763      20.997290
# album_record_label             0       NaN            NaN            NaN
# album_cover                   41       NaN            NaN            NaN
#
#                            min          25%            50%           75%  \
# track_uri                  NaN          NaN            NaN           NaN
# track_name                 NaN          NaN            NaN           NaN
# cleaned_track_name         NaN          NaN            NaN           NaN
# track_artists              NaN          NaN            NaN           NaN
# featured_artists           NaN          NaN            NaN           NaN
# track_is_explicit          NaN          NaN            NaN           NaN
# track_popularity           0.0      14.0000      29.000000      44.00000
# track_genres               NaN          NaN            NaN           NaN
# track_duration_ms       3338.0  177263.0000  214515.000000  259120.00000
# track_time_signature       0.0       4.0000       4.000000       4.00000
# track_acousticness         0.0       0.0377       0.192000       0.57800
# track_danceability         0.0       0.4480       0.582000       0.70100
# track_energy               0.0       0.4420       0.631000       0.78700
# track_key_signature        NaN          NaN            NaN           NaN
# track_instrumentalness     0.0       0.0000       0.000003       0.00118
# track_key                  0.0       2.0000       5.000000       8.00000
# track_mode                 0.0       0.0000       1.000000       1.00000
# track_liveness             0.0       0.1010       0.143000       0.31700
# track_loudness           -60.0     -10.2215      -7.278000      -5.40500
# track_speechiness          0.0       0.0363       0.052600       0.12400
# track_tempo                0.0      95.3085     119.984000     139.94900
# track_valence              0.0       0.2790       0.466000       0.66300
# track_lyrics               NaN          NaN            NaN           NaN
# lyrics_page_views       5001.0   13948.0000   38911.000000  132169.00000
# track_number               1.0       4.0000       8.000000      12.00000
# album_name                 NaN          NaN            NaN           NaN
# album_artist               NaN          NaN            NaN           NaN
# album_release_date         NaN          NaN            NaN           NaN
# album_popularity           0.0      32.0000      49.000000      63.00000
# album_record_label         NaN          NaN            NaN           NaN
# album_cover                NaN          NaN            NaN           NaN
#
#                                  max
# track_uri                        NaN
# track_name                       NaN
# cleaned_track_name               NaN
# track_artists                    NaN
# featured_artists                 NaN
# track_is_explicit                NaN
# track_popularity        9.700000e+01
# track_genres                     NaN
# track_duration_ms       4.794398e+06
# track_time_signature    5.000000e+00
# track_acousticness      9.960000e-01
# track_danceability      9.800000e-01
# track_energy            1.000000e+00
# track_key_signature              NaN
# track_instrumentalness  1.000000e+00
# track_key               1.100000e+01
# track_mode              1.000000e+00
# track_liveness          1.000000e+00
# track_loudness          9.320000e-01
# track_speechiness       9.660000e-01
# track_tempo             2.410050e+02
# track_valence           1.000000e+00
# track_lyrics                     NaN
# lyrics_page_views       2.335146e+07
# track_number            5.000000e+01
# album_name                       NaN
# album_artist                     NaN
# album_release_date               NaN
# album_popularity        1.000000e+02
# album_record_label               NaN
# album_cover                      NaN

# %% [markdown]
# #### Defining the Genres Column
# Based on the above description of the dataframe, it is observed that none of the tracks present have a genre. This is probably due to the restriction that spotify imposes on the object returned when accessing different endpoints. In order to obtain the missing values for the genres, the artist genre from the ArtistDetails.csv is used. Seeing as there are several subgenres of a specific genre under an artist. The genres will first be filtered to a general genres to be appended to each song and artist.

# %% [markdown]
# ##### Generating the Artist's Main Genres

# %%
artist_df = pd.read_csv('/Users/mariamtamer/VSCodeProjects/lyricalanalysis copy/2_Artist_Data_Acquisition/ArtistDetails.csv')

# %%
artist_df.head()
# Out:
#                                      uri    artist_name  \
# 0  spotify:artist:3TVXtAsR1Inumwj472S9r4          Drake
# 1  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  spotify:artist:4q3ewBCX7sLwd24euuV69X      Bad Bunny
# 3  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 4  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
#
#    artist_total_followers                                       artist_image  \
# 0                62430349  https://i.scdn.co/image/ab676161000051749e46a7...
# 1                95198498  https://i.scdn.co/image/ab6761610000517412a2ef...
# 2                46313053  https://i.scdn.co/image/ab676161000051746ad57a...
# 3                43517807  https://i.scdn.co/image/ab676161000051742f71b6...
# 4                78088925  https://i.scdn.co/image/ab67616100005174cdce76...
#
#                                               genres  popularity
# 0  ['canadian hip hop', 'canadian pop', 'hip hop'...          98
# 1                                  ['pop', 'uk pop']          96
# 2              ['latin', 'reggaeton', 'trap latino']         100
# 3  ['canadian contemporary r&b', 'canadian pop', ...          97
# 4                               ['dance pop', 'pop']          93

# %% [markdown]
# **Cleaning Column Names**

# %%
artist_df.rename(columns = {'uri':'artist_uri', 'genres': 'artist_genres', 'popularity': 'artist_popularity'}, inplace = True)

# %% [markdown]
# The following function retreives the unique genres from each row in the data frame and appends it to the list.

# %%
genres = []
def get_all_genres(row):
    for i in row:
        if i not in genres:
            genres.append(i)
        # if i not in artists_genres[artist]:
        #     artists_genres[artist].append(i)

# %% [markdown]
# Before applying the function on the data frame, it can be seen that the array is stored as a string inside the data frame so with the help of the literal_eval function which accepts strings of Python literals and can identify their structure to turn the string into a readable array.

# %%
# the array for the genres is saved as a string so it is important to turn it into an array before applying the function
from ast import literal_eval
artist_df['artist_genres'] = artist_df['artist_genres'].apply(literal_eval)

# %% [markdown]
# The genres are retrieved here using a lambda function

# %%
artist_df.apply(lambda x: get_all_genres(x.artist_genres), axis=1)
print(genres)
# Out:
# ['canadian hip hop', 'canadian pop', 'hip hop', 'rap', 'toronto rap', 'pop', 'uk pop', 'latin', 'reggaeton', 'trap latino', 'canadian contemporary r&b', 'dance pop', 'detroit hip hop', 'dfw rap', 'melodic rap', 'k-pop', 'k-pop boy group', 'reggaeton colombiano', 'chicago rap', 'art pop', 'electropop', 'permanent wave', 'emo rap', 'miami hip hop', 'puerto rican pop', 'pop r&b', 'modern rock', 'rock', 'slap house', 'barbadian pop', 'pop rap', 'urban contemporary', 'pop rock', 'viral pop', 'big room', 'edm', 'pop dance', 'electro house', 'house', 'progressive house', 'uk dance', 'latin hip hop', 'classic rock', 'glam rock', 'conscious hip hop', 'west coast rap', 'tropical house', 'boy band', 'post-teen pop', 'talent show', 'r&b', 'atl hip hop', 'southern hip hop', 'trap', 'hip pop', 'queens hip hop', 'north carolina hip hop', 'etherpop', 'indie poptimism', 'reggaeton flow', 'trap boricua', 'british soul', 'pop soul', 'beatlesque', 'british invasion', 'merseybeat', 'psychedelic rock', 'australian dance', 'australian pop', 'brostep', 'progressive electro house', 'alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'philly rap', 'alternative rock', 'funk metal', 'funk rock', 'garage rock', 'sheffield indie', 'colombian pop', 'latin pop', 'piano rock', 'soul', 'dutch edm', 'indie pop rap', 'oakland hip hop', 'moombahton', 'indietronica', 'metropopolis', 'new orleans rap', 'atl trap', 'gangster rap', 'panamanian pop', 'pittsburgh rap', 'brooklyn drill', 'ninja', 'emo', 'hard rock', 'metal', 'old school thrash', 'thrash metal', 'dmv rap', 'lgbtq+ hip hop', 'neo mellow', 'singer-songwriter', 'electronic trap', 'australian rock', 'girl group', 'seattle hip hop', 'complextro', 'german techno', 'florida rap', 'east coast hip hop', 'reggae', 'roots reggae', 'mellow gold', 'alternative r&b', 'neo soul', 'deep euro house', 'deep house', 'german dance', 'trance', 'punk', 'bachata', 'baton rouge rap', 'dirty south rap', 'uk funky', 'bolero', 'scandipop', 'swedish electropop', 'swedish pop', 'adult standards', 'jazz pop', 'lounge', 'mexican pop', 'album rock', 'art rock', 'progressive rock', 'symphonic rock', 'ohio hip hop', 'k-pop girl group', 'grunge', 'dark trap', 'underground hip hop', 'trap soul', 'arrocha', 'sertanejo', 'soft rock', 'yacht rock', 'hawaiian hip hop', 'glam metal', 'latin arena pop', 'banda', 'musica mexicana', 'norteno', 'funk carioca', 'funk pop', 'pagode baiano', 'pop nacional', 'modern alternative rock', 'shimmer pop', 'g funk', 'alternative hip hop', 'nz pop', 'australian hip hop', 'electro', 'contemporary r&b', 'south carolina hip hop', 'irish singer-songwriter', 'latin viral pop', 'rap latina', 'dance rock', 'contemporary country', 'country', 'irish rock', 'filter house', 'melancholia', 'oxford indie', 'canadian trap', 'pop punk', 'socal pop punk', 'easy listening', 'mississippi hip hop', 'modern folk rock', 'stomp and holler', 'uk americana', 'sertanejo universitario', 'plugg', 'pluggnb', 'rock-and-roll', 'rockabilly', 'hardcore hip hop', 'candy pop', 'pixie', 'pop emo', 'mariachi', 'nueva musica mexicana', 'ranchera', 'argentine hip hop', 'trap argentino', 'australian psych', 'neo-psychedelic', 'alt z', 'houston rap', 'trap queen', 'britpop', 'madchester', 'r&b en espanol', 'folk-pop', 'dancehall', 'country pop', 'country road', 'modern country rock', 'swedish synthpop', 'celtic rock', 'europop', 'groove metal', 'acoustic pop', 'baroque pop', 'uk alternative pop', 'country rock', 'southern rock', 'swamp rock', 'glee club', 'hollywood', 'heartland rock', 'canadian rock', 'german metal', 'industrial', 'industrial metal', 'industrial rock', 'neue deutsche harte', 'black americana', 'kentucky hip hop', 'german hip hop', 'vapor trap', 'melodic metalcore', 'metalcore', 'uk metalcore', 'arkansas country', 'outlaw country', 'cali rap', 'funk', 'indie r&b', 'motown', 'quiet storm', 'deep underground hip hop', 'nyc rap', 'german soundtrack', 'orchestral soundtrack', 'soundtrack', 'australian electropop', 'australian i ...

# %% [markdown]
# Since there are several subgenres for each genre (for example: canadian pop, soft pop, etc which would fall under pop), it is important to isolate the one word genres first which can work as standalone genres . This is done by checking to see if  the string contains no spaces and appending to a new list.

# %%
one_word_genres = []
for i in genres:
    if ' ' not in i:
        one_word_genres.append(i)
        
# for i in genres:
#     word = i.split(' ')
#     count = 0
#     for j in word:
#         if j in one_word_genres:
#             count +=1
#     if count == len(word):
#         one_word_genres.append(i)

# %%
print(one_word_genres)
# Out:
# ['rap', 'pop', 'latin', 'reggaeton', 'k-pop', 'electropop', 'rock', 'edm', 'house', 'r&b', 'trap', 'etherpop', 'beatlesque', 'merseybeat', 'brostep', 'post-grunge', 'soul', 'moombahton', 'indietronica', 'metropopolis', 'ninja', 'emo', 'metal', 'singer-songwriter', 'complextro', 'reggae', 'trance', 'punk', 'bachata', 'bolero', 'scandipop', 'lounge', 'grunge', 'arrocha', 'sertanejo', 'banda', 'norteno', 'electro', 'country', 'melancholia', 'plugg', 'pluggnb', 'rock-and-roll', 'rockabilly', 'pixie', 'mariachi', 'ranchera', 'neo-psychedelic', 'britpop', 'madchester', 'folk-pop', 'dancehall', 'europop', 'hollywood', 'industrial', 'metalcore', 'funk', 'motown', 'soundtrack', 'downtempo', 'forro', 'neo-singer-songwriter', 'tropical', 'cantautor', 'salsa', 'filmi', 'folk', 'disco', 'drill', 'ccm', 'worship', 'hoerspiel', 'nwobhm', 'champeta', 'vallenato', 'piseiro', 'grupera', 'sierreno', 'synthpop', 'proto-metal', 'nu-cumbia', 'grime', 'dembow', 'basshall', 'francoton', 'chillwave', 'neo-classical', 'corrido', 'celtic', 'opera', 'neo-synthpop', 'speedrun', 'lilith', 'g-house', 'pagode', 'dixieland', 'swing', 'sophisti-pop', 'afrofuturism', 'shoegaze', 'bubblegrunge', 'pianissimo', 'eurodance', 'classical', 'post-minimalism', 'cubaton', 'perreo', 'crunk', 'scorecore', 'supergroup', 'sleep', 'trova', 'lullaby', 'c-pop', 'mandopop', 'bluegrass', 'jamgrass', 'mpb', 'post-punk', 'zolo', 'dreamo', 'redneck', 'baroque', 'opm', 'anime', 'j-pop', 'j-poprock', 'j-rock', 'protopunk']

# %% [markdown]
# The one word strings are removed and any genres containing the one word strings as a substring are also removed from the genres list. This leaves a small amount of genres which are sorted manually in a new list called new_genres. The list is added to the one_word_genres.

# %%
# for i in one_word_genres:
#     for j in genres:
#         if i in j:
#             genres.remove(j)

for i in one_word_genres:
    if i in genres:
        genres.remove(i)

new_genres =  ['hip hop', 'permanent wave', 'contemporary r&b', 'contemporary', 'big room', 'dance', 'boy band', 'talent show', 'british invasion', 'indie', 
'thrash', 'neo mellow', 'girl group', 'german techno', 'mellow gold', 'german dance', 'adult standards', 'musica mexicana', 'alternative', 
'easy listening', 'stomp and holler', 'americana', 'psych', 'alt z', 'glee club', 'neue deutsche harte', 'quiet storm', 'show tunes', 
'escape room', 'french hip hop', 'mexican hip hop', 'a cappella', 'modern bollywood', 'acoustic cover', 'dream smp', 'spanish hip hop', 
'urbano espanol', 'christian music', 'melodic dubstep', 'new wave', 'eau claire indie', 'hardcore', 'ska argentino', 'vocal jazz', 
'contemporary vocal jazz', 'cancion melodica', 'athens indie', 'electric blues', 'compositional ambient', 'italian hip hop', 'middle earth', 
'jazz blues', 'ska mexicano', 'canzone napoletana', 'italian tenor', 'lo-fi indie', 'modern blues', 'video game music', 'harlem renaissance', 
'jazz trumpet', 'new orleans jazz', 'brooklyn indie', 'rock nacional brasileiro', 'palm desert scene', 'lo-fi cover', 'lo-fi product', 
'colombian hip hop', 'turkish hip hop', 'el paso indie', 'norwegian indie', 'lo-fi chill', "women's music", 'white noise', 'new french touch', 
'veracruz indie', 'batidao romantico', 'zhongguo feng', 'jam band', 'nashville sound', 'roots', 'bases de freestyle', 'techno', 'early music', 
'boom bap espanol', 'venezuelan hip hop', 'italian underground hip hop', 'visual kei', 'lo-fi', 'hardstyle', 'k-pop boy group', 'reggaeton colombiano', 
'latin hip hop', 'trap latino', 'rap latina']

one_word_genres.extend(new_genres)

print(one_word_genres)
# Out:
# ['rap', 'pop', 'latin', 'reggaeton', 'k-pop', 'electropop', 'rock', 'edm', 'house', 'r&b', 'trap', 'etherpop', 'beatlesque', 'merseybeat', 'brostep', 'post-grunge', 'soul', 'moombahton', 'indietronica', 'metropopolis', 'ninja', 'emo', 'metal', 'singer-songwriter', 'complextro', 'reggae', 'trance', 'punk', 'bachata', 'bolero', 'scandipop', 'lounge', 'grunge', 'arrocha', 'sertanejo', 'banda', 'norteno', 'electro', 'country', 'melancholia', 'plugg', 'pluggnb', 'rock-and-roll', 'rockabilly', 'pixie', 'mariachi', 'ranchera', 'neo-psychedelic', 'britpop', 'madchester', 'folk-pop', 'dancehall', 'europop', 'hollywood', 'industrial', 'metalcore', 'funk', 'motown', 'soundtrack', 'downtempo', 'forro', 'neo-singer-songwriter', 'tropical', 'cantautor', 'salsa', 'filmi', 'folk', 'disco', 'drill', 'ccm', 'worship', 'hoerspiel', 'nwobhm', 'champeta', 'vallenato', 'piseiro', 'grupera', 'sierreno', 'synthpop', 'proto-metal', 'nu-cumbia', 'grime', 'dembow', 'basshall', 'francoton', 'chillwave', 'neo-classical', 'corrido', 'celtic', 'opera', 'neo-synthpop', 'speedrun', 'lilith', 'g-house', 'pagode', 'dixieland', 'swing', 'sophisti-pop', 'afrofuturism', 'shoegaze', 'bubblegrunge', 'pianissimo', 'eurodance', 'classical', 'post-minimalism', 'cubaton', 'perreo', 'crunk', 'scorecore', 'supergroup', 'sleep', 'trova', 'lullaby', 'c-pop', 'mandopop', 'bluegrass', 'jamgrass', 'mpb', 'post-punk', 'zolo', 'dreamo', 'redneck', 'baroque', 'opm', 'anime', 'j-pop', 'j-poprock', 'j-rock', 'protopunk', 'hip hop', 'permanent wave', 'contemporary r&b', 'contemporary', 'big room', 'dance', 'boy band', 'talent show', 'british invasion', 'indie', 'thrash', 'neo mellow', 'girl group', 'german techno', 'mellow gold', 'german dance', 'adult standards', 'musica mexicana', 'alternative', 'easy listening', 'stomp and holler', 'americana', 'psych', 'alt z', 'glee club', 'neue deutsche harte', 'quiet storm', 'show tunes', 'escape room', 'french hip hop', 'mexican hip hop', 'a cappella', 'modern bollywood', 'acoustic cover', 'dream smp', 'spanish hip hop', 'urbano espanol', 'christian music', 'melodic dubstep', 'new wave', 'eau claire indie', 'hardcore', 'ska argentino', 'vocal jazz', 'contemporary vocal jazz', 'cancion melodica', 'athens indie', 'electric blues', 'compositional ambient', 'italian hip hop', 'middle earth', 'jazz blues', 'ska mexicano', 'canzone napoletana', 'italian tenor', 'lo-fi indie', 'modern blues', 'video game music', 'harlem renaissance', 'jazz trumpet', 'new orleans jazz', 'brooklyn indie', 'rock nacional brasileiro', 'palm desert scene', 'lo-fi cover', 'lo-fi product', 'colombian hip hop', 'turkish hip hop', 'el paso indie', 'norwegian indie', 'lo-fi chill', "women's music", 'white noise', 'new french touch', 'veracruz indie', 'batidao romantico', 'zhongguo feng', 'jam band', 'nashville sound', 'roots', 'bases de freestyle', 'techno', 'early music', 'boom bap espanol', 'venezuelan hip hop', 'italian underground hip hop', 'visual kei', 'lo-fi', 'hardstyle', 'k-pop boy group', 'reggaeton colombiano', 'latin hip hop', 'trap latino', 'rap latina']

# %% [markdown]
# The code is rerun to bring back strings that contain the genres that contain substrings of the one_word_genres defined earlier and and the list is rechecked to ensure no genres are lost.

# %%
for i in genres:
    word = i.split(' ')
    count = 0
    for j in word:
        if j in one_word_genres:
            count +=1
    if count == len(word):
        one_word_genres.append(i)

print(one_word_genres)
# Out:
# ['rap', 'pop', 'latin', 'reggaeton', 'k-pop', 'electropop', 'rock', 'edm', 'house', 'r&b', 'trap', 'etherpop', 'beatlesque', 'merseybeat', 'brostep', 'post-grunge', 'soul', 'moombahton', 'indietronica', 'metropopolis', 'ninja', 'emo', 'metal', 'singer-songwriter', 'complextro', 'reggae', 'trance', 'punk', 'bachata', 'bolero', 'scandipop', 'lounge', 'grunge', 'arrocha', 'sertanejo', 'banda', 'norteno', 'electro', 'country', 'melancholia', 'plugg', 'pluggnb', 'rock-and-roll', 'rockabilly', 'pixie', 'mariachi', 'ranchera', 'neo-psychedelic', 'britpop', 'madchester', 'folk-pop', 'dancehall', 'europop', 'hollywood', 'industrial', 'metalcore', 'funk', 'motown', 'soundtrack', 'downtempo', 'forro', 'neo-singer-songwriter', 'tropical', 'cantautor', 'salsa', 'filmi', 'folk', 'disco', 'drill', 'ccm', 'worship', 'hoerspiel', 'nwobhm', 'champeta', 'vallenato', 'piseiro', 'grupera', 'sierreno', 'synthpop', 'proto-metal', 'nu-cumbia', 'grime', 'dembow', 'basshall', 'francoton', 'chillwave', 'neo-classical', 'corrido', 'celtic', 'opera', 'neo-synthpop', 'speedrun', 'lilith', 'g-house', 'pagode', 'dixieland', 'swing', 'sophisti-pop', 'afrofuturism', 'shoegaze', 'bubblegrunge', 'pianissimo', 'eurodance', 'classical', 'post-minimalism', 'cubaton', 'perreo', 'crunk', 'scorecore', 'supergroup', 'sleep', 'trova', 'lullaby', 'c-pop', 'mandopop', 'bluegrass', 'jamgrass', 'mpb', 'post-punk', 'zolo', 'dreamo', 'redneck', 'baroque', 'opm', 'anime', 'j-pop', 'j-poprock', 'j-rock', 'protopunk', 'hip hop', 'permanent wave', 'contemporary r&b', 'contemporary', 'big room', 'dance', 'boy band', 'talent show', 'british invasion', 'indie', 'thrash', 'neo mellow', 'girl group', 'german techno', 'mellow gold', 'german dance', 'adult standards', 'musica mexicana', 'alternative', 'easy listening', 'stomp and holler', 'americana', 'psych', 'alt z', 'glee club', 'neue deutsche harte', 'quiet storm', 'show tunes', 'escape room', 'french hip hop', 'mexican hip hop', 'a cappella', 'modern bollywood', 'acoustic cover', 'dream smp', 'spanish hip hop', 'urbano espanol', 'christian music', 'melodic dubstep', 'new wave', 'eau claire indie', 'hardcore', 'ska argentino', 'vocal jazz', 'contemporary vocal jazz', 'cancion melodica', 'athens indie', 'electric blues', 'compositional ambient', 'italian hip hop', 'middle earth', 'jazz blues', 'ska mexicano', 'canzone napoletana', 'italian tenor', 'lo-fi indie', 'modern blues', 'video game music', 'harlem renaissance', 'jazz trumpet', 'new orleans jazz', 'brooklyn indie', 'rock nacional brasileiro', 'palm desert scene', 'lo-fi cover', 'lo-fi product', 'colombian hip hop', 'turkish hip hop', 'el paso indie', 'norwegian indie', 'lo-fi chill', "women's music", 'white noise', 'new french touch', 'veracruz indie', 'batidao romantico', 'zhongguo feng', 'jam band', 'nashville sound', 'roots', 'bases de freestyle', 'techno', 'early music', 'boom bap espanol', 'venezuelan hip hop', 'italian underground hip hop', 'visual kei', 'lo-fi', 'hardstyle', 'k-pop boy group', 'reggaeton colombiano', 'latin hip hop', 'trap latino', 'rap latina', 'dance pop', 'emo rap', 'pop r&b', 'pop rap', 'pop rock', 'pop dance', 'electro house', 'tropical house', 'pop soul', 'alternative metal', 'rap metal', 'alternative rock', 'funk metal', 'funk rock', 'latin pop', 'indie pop rap', 'thrash metal', 'roots reggae', 'alternative r&b', 'trap soul', 'funk pop', 'contemporary r&b', 'dance rock', 'contemporary country', 'pop punk', 'pop emo', 'country pop', 'celtic rock', 'baroque pop', 'country rock', 'industrial metal', 'industrial rock', 'indie r&b', 'latin rock', 'sertanejo pop', 'folk rock', 'roots rock', 'indie rock', 'indie folk', 'hardcore punk', 'latin alternative', 'rap rock', 'pop house', 'pop edm', 'alternative dance', 'indie pop', 'pop reggaeton', 'lo-fi indie', 'disco house', 'alternative pop rock', 'anime rock', 'country rap']

# %% [markdown]
# In order to obtain the main genres for each artist from the list defined, it is important to consider that there are unnecessary words that will not appear anywhere in the list. The first possible solution is to loop through the each artist genre from the list in the data frame and loop through the one_word_genres list defined and append when a match is met. However, seeing that there are genres that mix two of the main categories together, it is redundant to have the separate categories as well as the compound categories (for example: if an artist has 'canadian contemporary r&b', then his main genres would end up being 'contemporary', 'r&b', 'contemporary r&b'). This is very inefficient for the analysis since the artist will end up having 3 genres instead of one which would change the overall total of songs available for the genre.
#
# Therefore, the solution implemented involves finding the all the possible genres from the one word list defined above and appends them to a list before appending them to the main genres list. This is to avoid adding both single and compund genres for a compound genre. The longest match is found using the max function by iterating through the list and returning the genre with the longest string or in other words the best matched genre. The genre is returned as a tuple, an immutable type to indicate that it cannot be further modified and ensure that functions like nunique which help summarize data are working on the dataframe appropriately.

# %%
def simplify_genre(genres):
    artist_genre = []
    for i in genres:
        if i in one_word_genres and i not in artist_genre:
            artist_genre.append(i)
        else: 
            helper_list = []
            for j in one_word_genres:
                if j in i and j not in artist_genre:
                    helper_list.append(j)
            if (len(helper_list) > 0):
                res = max(helper_list, key=len)
                artist_genre.append(res)
    return tuple(artist_genre)

# %% [markdown]
# The function is then applied on the genres column and a new column is created with the simplified genres.

# %%
main_genres = artist_df.apply(lambda x: simplify_genre(x.artist_genres), axis= 1)
artist_df.insert(4, 'artist_main_genres', main_genres)
artist_df
# Out:
#                                 artist_uri    artist_name  \
# 0    spotify:artist:3TVXtAsR1Inumwj472S9r4          Drake
# 1    spotify:artist:6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2    spotify:artist:4q3ewBCX7sLwd24euuV69X      Bad Bunny
# 3    spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 4    spotify:artist:66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
# ..                                     ...            ...
# 994  spotify:artist:7FY5V3XMwlNBPitEjXowHQ  Darius Rucker
# 995  spotify:artist:6QtgPSJPSzcnn7dPZ4VINp       King Von
# 996  spotify:artist:66W9LaWS0DPdL7Sz8iYGYe        JP Saxe
# 997  spotify:artist:3gk0OYeLFWYupGFRHqLSR7        Showtek
# 998  spotify:artist:6EPlBSH2RSiettczlz7ihV  Sleepy Hallow
#
#      artist_total_followers  \
# 0                  62430349
# 1                  95198498
# 2                  46313053
# 3                  43517807
# 4                  78088925
# ..                      ...
# 994                 2161236
# 995                 1853606
# 996                  339184
# 997                  452048
# 998                  807254
#
#                                           artist_image  \
# 0    https://i.scdn.co/image/ab676161000051749e46a7...
# 1    https://i.scdn.co/image/ab6761610000517412a2ef...
# 2    https://i.scdn.co/image/ab676161000051746ad57a...
# 3    https://i.scdn.co/image/ab676161000051742f71b6...
# 4    https://i.scdn.co/image/ab67616100005174cdce76...
# ..                                                 ...
# 994  https://i.scdn.co/image/ab676161000051748e5582...
# 995  https://i.scdn.co/image/ab676161000051745c0b21...
# 996  https://i.scdn.co/image/ab67616100005174e1963b...
# 997  https://i.scdn.co/image/ab676161000051746ac094...
# 998  https://i.scdn.co/image/ab67616100005174855638...
#
#                                     artist_main_genres  \
# 0                                  (hip hop, pop, rap)
# 1                                               (pop,)
# 2                      (latin, reggaeton, trap latino)
# 3                              (contemporary r&b, pop)
# 4                                     (dance pop, pop)
# ..                                                 ...
# 994         (americana, contemporary country, country)
# 995                                             (rap,)
# 996                     (alt z, contemporary r&b, pop)
# 997  (hardstyle, edm, electro house, pop dance, ele...
# 998                                       (drill, rap)
#
#                                          artist_genres  artist_popularity
# 0    [canadian hip hop, canadian pop, hip hop, rap,...                 98
# 1                                        [pop, uk pop]                 96
# 2                      [latin, reggaeton, trap latino]                100
# 3       [canadian contemporary r&b, canadian pop, pop]                 97
# 4                                     [dance pop, pop]                 93
# ..                                                 ...                ...
# 994  [black americana, contemporary country, countr...                 70
# 995                                      [chicago rap]                 82
# 996            [alt z, canadian contemporary r&b, pop]                 73
# 997  [classic hardstyle, edm, electro house, euphor...                 67
# 998                          [brooklyn drill, nyc rap]                 81
#
# [999 rows x 7 columns]

# %%
output_path="ArtistWithGenres.csv"
artist_df.to_csv(output_path)

# %% [markdown]
# ##### Appending Genres to Track Based on Artist
#
# The track artists are checked and their corresponding genres are appended to the genres list for the track. Again, the genres are returned as a tuple to maintain immutability.

# %%
def get_genre(artist_list):
    genres = []
    for artist in artist_list:
        if artist in artist_df['artist_name'].values:
            genres_cell = artist_df.loc[artist_df['artist_name'] == artist, 'artist_main_genres'].values[0]
            for genre in genres_cell:
                if genre not in genres:
                    genres.append(genre)
    return tuple(genres)

#save = get_genre(['Drake', 'Ed Sheeran', 'Ariana Grande'])
#print(save)

# %% [markdown]
# Similar to the genres in the artist_df, the track artists array is stored as a string inside the data frame so with literal_eval is used to turn the string into a readable array.

# %%
from ast import literal_eval
df['track_artists'] = df['track_artists'].apply(literal_eval)

# %% [markdown]
# The same is done with the featured artists. But beforehand, the np.nan values are replaced with string None values since literal_eval only operates on strings and would throw a NoneType error if no string value was passed to it.

# %%
df['featured_artists'] = df.featured_artists.replace(np.nan,'None')
df['featured_artists'] = df['featured_artists'].apply(literal_eval)

# %%
df
# Out:
#                                    track_uri  \
# 0       spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1       spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2       spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3       spotify:track:61S79KIVA4I9FXbnsylEHT
# 4       spotify:track:4VCbgIdr8ptegWeJpqLVHH
# ...                                      ...
# 159226  spotify:track:0VxTtE5HoNMf9sp30j6c9V
# 159227  spotify:track:3EHx4H0FsTplZrcFSeuLeE
# 159228  spotify:track:4GfGx2zvY8pIwf2o2SAufU
# 159229  spotify:track:7dODnrD8danC9FD5xLb9Tu
# 159230  spotify:track:76F74qIRn19FmIdl6mMQAP
#
#                                    track_name             cleaned_track_name  \
# 0                            Champagne Poetry               Champagne Poetry
# 1                                 Papi’s Home                    Papi’s Home
# 2            Girls Want Girls (with Lil Baby)                            NaN
# 3       In The Bible (with Lil Durk & Giveon)                   In The Bible
# 4                       Love All (with JAY-Z)                            NaN
# ...                                       ...                            ...
# 159226                              Try Again                            NaN
# 159227              What I Want Is What I Got   What I Want Is What I’ve Got
# 159228                             We Are One                            NaN
# 159229          Can't Lose What You Never Had  Can’t Lose What You Never Had
# 159230                       My Private Movie               My Private Movie
#
#                     track_artists    featured_artists  track_is_explicit  \
# 0                         [Drake]                None               True
# 1                         [Drake]                None               True
# 2               [Drake, Lil Baby]                None               True
# 3       [Drake, Lil Durk, Giveon]  [GIVĒON, Lil Durk]               True
# 4                  [Drake, JAY-Z]                None               True
# ...                           ...                 ...                ...
# 159226                 [Westlife]                None              False
# 159227                 [Westlife]                None              False
# 159228                 [Westlife]                None              False
# 159229                 [Westlife]                None              False
# 159230                 [Westlife]                None              False
#
#         track_popularity  track_genres  track_duration_ms  \
# 0                     82           NaN             336511
# 1                     76           NaN             178623
# 2                     86           NaN             221979
# 3                     79           NaN             296568
# 4                     77           NaN             228461
# ...                  ...           ...                ...
# 159226                47           NaN             214866
# 159227                46           NaN             213066
# 159228                45           NaN             222893
# 159229                45           NaN             264485
# 159230                37           NaN             244733
#
#         track_time_signature  ...  track_valence  \
# 0                        4.0  ...          0.496
# 1                        4.0  ...          0.588
# 2                        4.0  ...          0.381
# 3                        4.0  ...          0.147
# 4                        4.0  ...          0.155
# ...                      ...  ...            ...
# 159226                   3.0  ...          0.381
# 159227                   4.0  ...          0.744
# 159228                   4.0  ...          0.426
# 159229                   4.0  ...          0.656
# 159230                   3.0  ...          0.265
#
#                                              track_lyrics  lyrics_page_views  \
# 0       Champagne Poetry Lyrics\n\nI love you, I love ...           688853.0
# 1       Papi’s Home Lyrics\nI know that I hurt you\nYe...           445883.0
# 2                                                     NaN                NaN
# 3       In The Bible Lyrics\nOkay, okay, okay\nCountin...           439186.0
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 159226                                                NaN                NaN
# 159227  What I Want Is What I’ve Got Lyrics\nAll that ...                NaN
# 159228                                                NaN                NaN
# 159229  Can’t Lose What You Never Had Lyrics\nBaby you...             6644.0
# 159230  My Private Movie LyricsPretty girls are all ar...                NaN
#
#        track_number           album_name  album_artist  album_release_date  \
# 0                 1  Certified Lover Boy         Drake          2021-09-03
# 1                 2  Certified Lover Boy         Drake          2021-09-03
# 2                 3  Certified Lover Boy         Drake          2021-09-03
# 3                 4  Certified Lover Boy         Drake          2021-09-03
# 4                 5  Certified Lover Boy         Drake          2021-09-03
# ...             ...                  ...           ...                 ...
# 159226           14             Westlife      Westlife          1999-11-01
# 159227           15             Westlife      Westlife          1999-11-01
# 159228           16             Westlife      Westlife          1999-11-01
# 159229           17             Westlife      Westlife          1999-11-01
# 159230           18             Westlife      Westlife          1999-11-01
#
#         album_popularity  album_record_label  \
# 0                     95                 OVO
# 1                     95                 OVO
# 2                     95                 OVO
# 3                     95                 OVO
# 4                     95                 OVO
# ...                  ...                 ...
# 159226                73   RCA Records Label
# 159227                73   RCA Records Label
# 159228                73   RCA Records Label
# 159229                73   RCA Records Label
# 159230                73   RCA Records Label
#
#                                               album_cover
# 0       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 1       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 2       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 3       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 4       https://i.scdn.co/image/ab67616d00001e02cd945b...
# ...                                                   ...
# 159226  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159227  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159228  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159229  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159230  https://i.scdn.co/image/ab67616d00001e0244ead2...
#
# [159231 rows x 31 columns]

# %% [markdown]
# The next two functions are used to convert the track_artist and featured_artist column values into tuples to ensure that they are immutable types and to allow data frame description functions to be used later without throwing errors.

# %%
def convert(list):
    return tuple(list)

def convert_with_none(list):
    if list == None:
        return np.nan
    return tuple(list)

# %% [markdown]
# The functions are applied on each of the columns. Since featured artists contains none type data which are not iterable, the function applied checks for none type and returns np.nan to maintain consistency of the dataframe.

# %%
df['track_artists'] = df.apply(lambda x: convert(x.track_artists), axis=1)

df['featured_artists'] = df.apply(lambda x: convert_with_none(x.featured_artists), axis=1)

# %% [markdown]
# The get genre function is then applied on  the dataframe by iterating through the track artists and returning their combined genres as found in track_genres column.

# %%
track_genres = df.apply(lambda x: get_genre(x.track_artists), axis= 1)
df['track_genres'] = track_genres
df
# Out:
#                                    track_uri  \
# 0       spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1       spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2       spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3       spotify:track:61S79KIVA4I9FXbnsylEHT
# 4       spotify:track:4VCbgIdr8ptegWeJpqLVHH
# ...                                      ...
# 159226  spotify:track:0VxTtE5HoNMf9sp30j6c9V
# 159227  spotify:track:3EHx4H0FsTplZrcFSeuLeE
# 159228  spotify:track:4GfGx2zvY8pIwf2o2SAufU
# 159229  spotify:track:7dODnrD8danC9FD5xLb9Tu
# 159230  spotify:track:76F74qIRn19FmIdl6mMQAP
#
#                                    track_name             cleaned_track_name  \
# 0                            Champagne Poetry               Champagne Poetry
# 1                                 Papi’s Home                    Papi’s Home
# 2            Girls Want Girls (with Lil Baby)                            NaN
# 3       In The Bible (with Lil Durk & Giveon)                   In The Bible
# 4                       Love All (with JAY-Z)                            NaN
# ...                                       ...                            ...
# 159226                              Try Again                            NaN
# 159227              What I Want Is What I Got   What I Want Is What I’ve Got
# 159228                             We Are One                            NaN
# 159229          Can't Lose What You Never Had  Can’t Lose What You Never Had
# 159230                       My Private Movie               My Private Movie
#
#                     track_artists    featured_artists  track_is_explicit  \
# 0                        (Drake,)                 NaN               True
# 1                        (Drake,)                 NaN               True
# 2               (Drake, Lil Baby)                 NaN               True
# 3       (Drake, Lil Durk, Giveon)  (GIVĒON, Lil Durk)               True
# 4                  (Drake, JAY-Z)                 NaN               True
# ...                           ...                 ...                ...
# 159226                (Westlife,)                 NaN              False
# 159227                (Westlife,)                 NaN              False
# 159228                (Westlife,)                 NaN              False
# 159229                (Westlife,)                 NaN              False
# 159230                (Westlife,)                 NaN              False
#
#         track_popularity                           track_genres  \
# 0                     82                    (hip hop, pop, rap)
# 1                     76                    (hip hop, pop, rap)
# 2                     86              (hip hop, pop, rap, trap)
# 3                     79  (hip hop, pop, rap, drill, trap, r&b)
# 4                     77                    (hip hop, pop, rap)
# ...                  ...                                    ...
# 159226                47         (boy band, dance pop, europop)
# 159227                46         (boy band, dance pop, europop)
# 159228                45         (boy band, dance pop, europop)
# 159229                45         (boy band, dance pop, europop)
# 159230                37         (boy band, dance pop, europop)
#
#         track_duration_ms  track_time_signature  ...  track_valence  \
# 0                  336511                   4.0  ...          0.496
# 1                  178623                   4.0  ...          0.588
# 2                  221979                   4.0  ...          0.381
# 3                  296568                   4.0  ...          0.147
# 4                  228461                   4.0  ...          0.155
# ...                   ...                   ...  ...            ...
# 159226             214866                   3.0  ...          0.381
# 159227             213066                   4.0  ...          0.744
# 159228             222893                   4.0  ...          0.426
# 159229             264485                   4.0  ...          0.656
# 159230             244733                   3.0  ...          0.265
#
#                                              track_lyrics  lyrics_page_views  \
# 0       Champagne Poetry Lyrics\n\nI love you, I love ...           688853.0
# 1       Papi’s Home Lyrics\nI know that I hurt you\nYe...           445883.0
# 2                                                     NaN                NaN
# 3       In The Bible Lyrics\nOkay, okay, okay\nCountin...           439186.0
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 159226                                                NaN                NaN
# 159227  What I Want Is What I’ve Got Lyrics\nAll that ...                NaN
# 159228                                                NaN                NaN
# 159229  Can’t Lose What You Never Had Lyrics\nBaby you...             6644.0
# 159230  My Private Movie LyricsPretty girls are all ar...                NaN
#
#        track_number           album_name  album_artist  album_release_date  \
# 0                 1  Certified Lover Boy         Drake          2021-09-03
# 1                 2  Certified Lover Boy         Drake          2021-09-03
# 2                 3  Certified Lover Boy         Drake          2021-09-03
# 3                 4  Certified Lover Boy         Drake          2021-09-03
# 4                 5  Certified Lover Boy         Drake          2021-09-03
# ...             ...                  ...           ...                 ...
# 159226           14             Westlife      Westlife          1999-11-01
# 159227           15             Westlife      Westlife          1999-11-01
# 159228           16             Westlife      Westlife          1999-11-01
# 159229           17             Westlife      Westlife          1999-11-01
# 159230           18             Westlife      Westlife          1999-11-01
#
#         album_popularity  album_record_label  \
# 0                     95                 OVO
# 1                     95                 OVO
# 2                     95                 OVO
# 3                     95                 OVO
# 4                     95                 OVO
# ...                  ...                 ...
# 159226                73   RCA Records Label
# 159227                73   RCA Records Label
# 159228                73   RCA Records Label
# 159229                73   RCA Records Label
# 159230                73   RCA Records Label
#
#                                               album_cover
# 0       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 1       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 2       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 3       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 4       https://i.scdn.co/image/ab67616d00001e02cd945b...
# ...                                                   ...
# 159226  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159227  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159228  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159229  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 159230  https://i.scdn.co/image/ab67616d00001e0244ead2...
#
# [159231 rows x 31 columns]

# %%
describ = df.describe() # assign describe to variable
null_sum = pd.concat([df.isnull().sum().rename('NullData'),describ.T],axis=1)

# %%
null_sum
# Out:
#                         NullData     count           mean            std  \
# track_uri                      0       NaN            NaN            NaN
# track_name                     0       NaN            NaN            NaN
# cleaned_track_name         67860       NaN            NaN            NaN
# track_artists                  0       NaN            NaN            NaN
# featured_artists          144057       NaN            NaN            NaN
# track_is_explicit              0       NaN            NaN            NaN
# track_popularity               0  159231.0      30.132688      19.650210
# track_genres                   0       NaN            NaN            NaN
# track_duration_ms              0  159231.0  226734.568445  109223.122570
# track_time_signature          48  159183.0       3.900932       0.448415
# track_acousticness            48  159183.0       0.318934       0.318564
# track_danceability            48  159183.0       0.566812       0.178980
# track_energy                  48  159183.0       0.599635       0.236088
# track_key_signature           48       NaN            NaN            NaN
# track_instrumentalness        48  159183.0       0.080285       0.230314
# track_key                     48  159183.0       5.206492       3.573586
# track_mode                    48  159183.0       0.657357       0.474595
# track_liveness                48  159183.0       0.256745       0.245704
# track_loudness                48  159183.0      -8.462706       4.572328
# track_speechiness             48  159183.0       0.114471       0.143858
# track_tempo                   48  159183.0     120.008114      30.345771
# track_valence                 48  159183.0       0.474591       0.246683
# track_lyrics               73160       NaN            NaN            NaN
# lyrics_page_views         113530   45701.0  174480.623838  541857.683513
# track_number                   0  159231.0       8.916128       6.524022
# album_name                     0       NaN            NaN            NaN
# album_artist                   0       NaN            NaN            NaN
# album_release_date             0       NaN            NaN            NaN
# album_popularity               0  159231.0      47.024763      20.997290
# album_record_label             0       NaN            NaN            NaN
# album_cover                   41       NaN            NaN            NaN
#
#                            min          25%            50%           75%  \
# track_uri                  NaN          NaN            NaN           NaN
# track_name                 NaN          NaN            NaN           NaN
# cleaned_track_name         NaN          NaN            NaN           NaN
# track_artists              NaN          NaN            NaN           NaN
# featured_artists           NaN          NaN            NaN           NaN
# track_is_explicit          NaN          NaN            NaN           NaN
# track_popularity           0.0      14.0000      29.000000      44.00000
# track_genres               NaN          NaN            NaN           NaN
# track_duration_ms       3338.0  177263.0000  214515.000000  259120.00000
# track_time_signature       0.0       4.0000       4.000000       4.00000
# track_acousticness         0.0       0.0377       0.192000       0.57800
# track_danceability         0.0       0.4480       0.582000       0.70100
# track_energy               0.0       0.4420       0.631000       0.78700
# track_key_signature        NaN          NaN            NaN           NaN
# track_instrumentalness     0.0       0.0000       0.000003       0.00118
# track_key                  0.0       2.0000       5.000000       8.00000
# track_mode                 0.0       0.0000       1.000000       1.00000
# track_liveness             0.0       0.1010       0.143000       0.31700
# track_loudness           -60.0     -10.2215      -7.278000      -5.40500
# track_speechiness          0.0       0.0363       0.052600       0.12400
# track_tempo                0.0      95.3085     119.984000     139.94900
# track_valence              0.0       0.2790       0.466000       0.66300
# track_lyrics               NaN          NaN            NaN           NaN
# lyrics_page_views       5001.0   13948.0000   38911.000000  132169.00000
# track_number               1.0       4.0000       8.000000      12.00000
# album_name                 NaN          NaN            NaN           NaN
# album_artist               NaN          NaN            NaN           NaN
# album_release_date         NaN          NaN            NaN           NaN
# album_popularity           0.0      32.0000      49.000000      63.00000
# album_record_label         NaN          NaN            NaN           NaN
# album_cover                NaN          NaN            NaN           NaN
#
#                                  max
# track_uri                        NaN
# track_name                       NaN
# cleaned_track_name               NaN
# track_artists                    NaN
# featured_artists                 NaN
# track_is_explicit                NaN
# track_popularity        9.700000e+01
# track_genres                     NaN
# track_duration_ms       4.794398e+06
# track_time_signature    5.000000e+00
# track_acousticness      9.960000e-01
# track_danceability      9.800000e-01
# track_energy            1.000000e+00
# track_key_signature              NaN
# track_instrumentalness  1.000000e+00
# track_key               1.100000e+01
# track_mode              1.000000e+00
# track_liveness          1.000000e+00
# track_loudness          9.320000e-01
# track_speechiness       9.660000e-01
# track_tempo             2.410050e+02
# track_valence           1.000000e+00
# track_lyrics                     NaN
# lyrics_page_views       2.335146e+07
# track_number            5.000000e+01
# album_name                       NaN
# album_artist                     NaN
# album_release_date               NaN
# album_popularity        1.000000e+02
# album_record_label               NaN
# album_cover                      NaN

# %% [markdown]
# As demonstrated by the data description, the genres are no longer null. However there are still multiple null values for the lyrics which can be due to the many instrumental songs, live versions, and remixes of an already existing song in the list.

# %% [markdown]
# #### Lyrics Cleanup

# %% [markdown]
# Before beginning the lyric clean up, let's take a look at the unique values for each  column in the dataframe.

# %%
# To find how many unique values columns have
df.nunique()
# Out:
# track_uri                 156480
# track_name                105118
# cleaned_track_name         57046
# track_artists              17885
# featured_artists            5782
# track_is_explicit              2
# track_popularity              98
# track_genres                2867
# track_duration_ms          53780
# track_time_signature           5
# track_acousticness          4155
# track_danceability          1151
# track_energy                1898
# track_key_signature           24
# track_instrumentalness      5290
# track_key                     12
# track_mode                     2
# track_liveness              1668
# track_loudness             18448
# track_speechiness           1594
# track_tempo                44084
# track_valence               1650
# track_lyrics               57965
# lyrics_page_views          26616
# track_number                  50
# album_name                  9574
# album_artist                 797
# album_release_date          3772
# album_popularity             100
# album_record_label          1448
# album_cover                 9752
# dtype: int64

# %% [markdown]
# Seeing that the track_uri sum of unique values does not equal the total data of 159231, it can be deduced that there are tracks with the same uri or in other words duplicates since the uri is the unique identifier for a song as in the Spotify API documentation. Thus, the duplicates can be further explored.

# %%
df[df['track_uri'].isin(df['track_uri'][df['track_uri'].duplicated()])].sort_values(by='track_uri')
# Out:
#                                    track_uri  \
# 18746   spotify:track:00KjOnN3U40e3lXFUOue7h
# 26592   spotify:track:00KjOnN3U40e3lXFUOue7h
# 70784   spotify:track:00Qt1c8zamewy9XXUWwm7P
# 73107   spotify:track:00Qt1c8zamewy9XXUWwm7P
# 52502   spotify:track:00Y9yFHumsN6Cg4cK3wXkM
# ...                                      ...
# 72831   spotify:track:7zi8UxAGIpaaymfzfHvOB7
# 55218   spotify:track:7zkbsyd1GfiCtoF7uxLBS7
# 27564   spotify:track:7zkbsyd1GfiCtoF7uxLBS7
# 147637  spotify:track:7zkyxCoflcjvxjJaEPZ5J9
# 153566  spotify:track:7zkyxCoflcjvxjJaEPZ5J9
#
#                                                track_name  \
# 18746              10AM/Save The World (feat. Gucci Mane)
# 26592              10AM/Save The World (feat. Gucci Mane)
# 70784                                      Rakata - Remix
# 73107                                      Rakata - Remix
# 52502                   Cap (feat. Trouble) - From Jxmtro
# ...                                                   ...
# 72831                                           Tu Nombre
# 55218                                             Changed
# 27564                                             Changed
# 147637  Oh Bess, Oh Where's My Bess? (From "Porgy and ...
# 153566  Oh Bess, Oh Where's My Bess? (From "Porgy and ...
#
#            cleaned_track_name  \
# 18746   10AM / Save the World
# 26592   10AM / Save the World
# 70784          Rakata (Remix)
# 73107          Rakata (Remix)
# 52502                     NaN
# ...                       ...
# 72831                     NaN
# 55218                     NaN
# 27564                     NaN
# 147637                    NaN
# 153566                    NaN
#
#                                             track_artists  \
# 18746                          (Metro Boomin, Gucci Mane)
# 26592                          (Metro Boomin, Gucci Mane)
# 70784                           (Wisin & Yandel, Ja Rule)
# 73107                           (Wisin & Yandel, Ja Rule)
# 52502       (Rae Sremmurd, Swae Lee, Slim Jxmmi, Trouble)
# ...                                                   ...
# 72831                                   (Wisin & Yandel,)
# 55218                       (YoungBoy Never Broke Again,)
# 27564                       (YoungBoy Never Broke Again,)
# 147637  (Louis Armstrong, Russell Garcia and His Orche...
# 153566  (Louis Armstrong, Russell Garcia and His Orche...
#
#                     featured_artists  track_is_explicit  track_popularity  \
# 18746                  (Gucci Mane,)               True                60
# 26592                  (Gucci Mane,)               True                60
# 70784   (N.O.R.E., Ja Rule, Pitbull)              False                52
# 73107   (N.O.R.E., Ja Rule, Pitbull)              False                52
# 52502                            NaN               True                37
# ...                              ...                ...               ...
# 72831                            NaN              False                 9
# 55218                            NaN               True                43
# 27564                            NaN               True                43
# 147637                           NaN              False                17
# 153566                           NaN              False                17
#
#                                              track_genres  track_duration_ms  \
# 18746                       (hip hop, pop rap, rap, trap)             226320
# 26592                       (hip hop, pop rap, rap, trap)             226320
# 70784   (electro, latin, latin hip hop, reggaeton, tra...             211186
# 73107   (electro, latin, latin hip hop, reggaeton, tra...             211186
# 52502                       (hip hop, rap, pop rap, trap)             192000
# ...                                                   ...                ...
# 72831   (electro, latin, latin hip hop, reggaeton, tra...             271360
# 55218                                         (rap, trap)             191351
# 27564                                         (rap, trap)             191351
# 147637  (adult standards, dixieland, harlem renaissanc...             157480
# 153566  (adult standards, dixieland, harlem renaissanc...             157480
#
#         track_time_signature  ...  track_valence  \
# 18746                    4.0  ...          0.842
# 26592                    4.0  ...          0.130
# 70784                    4.0  ...          0.314
# 73107                    4.0  ...          0.314
# 52502                    4.0  ...          0.726
# ...                      ...  ...            ...
# 72831                    4.0  ...          0.668
# 55218                    4.0  ...          0.377
# 27564                    4.0  ...          0.539
# 147637                   4.0  ...          0.298
# 153566                   3.0  ...          0.695
#
#                                              track_lyrics  lyrics_page_views  \
# 18746   10AM / Save the World Lyrics\nYeah\nYeah, good...            91702.0
# 26592   10AM / Save the World Lyrics\nYeah\nYeah, good...            91720.0
# 70784   Rakata (Remix) LyricsDJ any one w el sobrebivi...                NaN
# 73107   Rakata (Remix) LyricsDJ any one w el sobrebivi...                NaN
# 52502                                                 NaN                NaN
# ...                                                   ...                ...
# 72831                                                 NaN                NaN
# 55218                                                 NaN                NaN
# 27564                                                 NaN                NaN
# 147637                                                NaN                NaN
# 153566                                                NaN                NaN
#
#        track_number                           album_name  \
# 18746             1   NOT ALL HEROES WEAR CAPES (Deluxe)
# 26592             1   NOT ALL HEROES WEAR CAPES (Deluxe)
# 70784            20                           Pa'l Mundo
# 73107            20                           Pa'l Mundo
# 52502             5                                SR3MM
# ...             ...                                  ...
# 72831             1              Líderes (Muve Sessions)
# 55218             4        Mind of a Menace 3 (Reloaded)
# 27564             4        Mind of a Menace 3 (Reloaded)
# 147637           14  Milestones of a Jazz Legend, Vol. 6
# 153566           14  Milestones of a Jazz Legend, Vol. 6
#
#                       album_artist  album_release_date  album_popularity  \
# 18746                 Metro Boomin          2018-11-06                84
# 26592                 Metro Boomin          2018-11-06                84
# 70784               Wisin & Yandel          2005-11-08                56
# 73107               Wisin & Yandel          2005-11-08                56
# 52502                 Rae Sremmurd          2018-05-04                72
# ...                            ...                 ...               ...
# 72831               Wisin & Yandel          2012-01-01                22
# 55218   YoungBoy Never Broke Again          2016-10-21                50
# 27564   YoungBoy Never Broke Again          2016-10-21                50
# 147637             Ella Fitzgerald          2021-10-22                27
# 153566             Ella Fitzgerald          2021-10-22                27
#
#             album_record_label  \
# 18746         Republic Records
# 26592         Republic Records
# 70784            Machete Music
# 73107            Machete Music
# 52502        Mike WiLL Made-It
# ...                        ...
# 72831           UMLE - Machete
# 55218   Never Broke Again, LLC
# 27564   Never Broke Again, LLC
# 147637      Intense Media GmbH
# 153566      Intense Media GmbH
#
#                                               album_cover
# 18746   https://i.scdn.co/image/ab67616d00001e022887f8...
# 26592   https://i.scdn.co/image/ab67616d00001e022887f8...
# 70784   https://i.scdn.co/image/ab67616d00001e023b2fe6...
# 73107   https://i.scdn.co/image/ab67616d00001e023b2fe6...
# 52502   https://i.scdn.co/image/ab67616d00001e02ba9015...
# ...                                                   ...
# 72831   https://i.scdn.co/image/ab67616d00001e02eb0282...
# 55218   https://i.scdn.co/image/ab67616d00001e02f59909...
# 27564   https://i.scdn.co/image/ab67616d00001e02f59909...
# 147637  https://i.scdn.co/image/ab67616d00001e0244550b...
# 153566  https://i.scdn.co/image/ab67616d00001e0244550b...
#
# [5395 rows x 31 columns]

# %% [markdown]
# All 5395 duplicates identified are true duplicates with the same features as they were taken from the same track uri endpoint and lyric endpoint. Therefore it is safe to drop the duplicates leaving only their first appearance without affecting data analysis, 2644 dropped to be exact. Out of all duplicates, there are about 1880 tracks where the lyrics are unavailable due to the song being instrumental or the lyrics not added yet.

# %%
df.drop_duplicates(subset='track_uri', keep="first", inplace=True, ignore_index=True)

# %%
df
# Out:
#                                    track_uri  \
# 0       spotify:track:2HSmyk2qMN8WQjuGhaQgCk
# 1       spotify:track:6jy9yJfgCsMHdu2Oz4BGKX
# 2       spotify:track:37Nqx7iavZpotJSDXZWbJ3
# 3       spotify:track:61S79KIVA4I9FXbnsylEHT
# 4       spotify:track:4VCbgIdr8ptegWeJpqLVHH
# ...                                      ...
# 156475  spotify:track:0VxTtE5HoNMf9sp30j6c9V
# 156476  spotify:track:3EHx4H0FsTplZrcFSeuLeE
# 156477  spotify:track:4GfGx2zvY8pIwf2o2SAufU
# 156478  spotify:track:7dODnrD8danC9FD5xLb9Tu
# 156479  spotify:track:76F74qIRn19FmIdl6mMQAP
#
#                                    track_name             cleaned_track_name  \
# 0                            Champagne Poetry               Champagne Poetry
# 1                                 Papi’s Home                    Papi’s Home
# 2            Girls Want Girls (with Lil Baby)                            NaN
# 3       In The Bible (with Lil Durk & Giveon)                   In The Bible
# 4                       Love All (with JAY-Z)                            NaN
# ...                                       ...                            ...
# 156475                              Try Again                            NaN
# 156476              What I Want Is What I Got   What I Want Is What I’ve Got
# 156477                             We Are One                            NaN
# 156478          Can't Lose What You Never Had  Can’t Lose What You Never Had
# 156479                       My Private Movie               My Private Movie
#
#                     track_artists    featured_artists  track_is_explicit  \
# 0                        (Drake,)                 NaN               True
# 1                        (Drake,)                 NaN               True
# 2               (Drake, Lil Baby)                 NaN               True
# 3       (Drake, Lil Durk, Giveon)  (GIVĒON, Lil Durk)               True
# 4                  (Drake, JAY-Z)                 NaN               True
# ...                           ...                 ...                ...
# 156475                (Westlife,)                 NaN              False
# 156476                (Westlife,)                 NaN              False
# 156477                (Westlife,)                 NaN              False
# 156478                (Westlife,)                 NaN              False
# 156479                (Westlife,)                 NaN              False
#
#         track_popularity                           track_genres  \
# 0                     82                    (hip hop, pop, rap)
# 1                     76                    (hip hop, pop, rap)
# 2                     86              (hip hop, pop, rap, trap)
# 3                     79  (hip hop, pop, rap, drill, trap, r&b)
# 4                     77                    (hip hop, pop, rap)
# ...                  ...                                    ...
# 156475                47         (boy band, dance pop, europop)
# 156476                46         (boy band, dance pop, europop)
# 156477                45         (boy band, dance pop, europop)
# 156478                45         (boy band, dance pop, europop)
# 156479                37         (boy band, dance pop, europop)
#
#         track_duration_ms  track_time_signature  ...  track_valence  \
# 0                  336511                   4.0  ...          0.496
# 1                  178623                   4.0  ...          0.588
# 2                  221979                   4.0  ...          0.381
# 3                  296568                   4.0  ...          0.147
# 4                  228461                   4.0  ...          0.155
# ...                   ...                   ...  ...            ...
# 156475             214866                   3.0  ...          0.381
# 156476             213066                   4.0  ...          0.744
# 156477             222893                   4.0  ...          0.426
# 156478             264485                   4.0  ...          0.656
# 156479             244733                   3.0  ...          0.265
#
#                                              track_lyrics  lyrics_page_views  \
# 0       Champagne Poetry Lyrics\n\nI love you, I love ...           688853.0
# 1       Papi’s Home Lyrics\nI know that I hurt you\nYe...           445883.0
# 2                                                     NaN                NaN
# 3       In The Bible Lyrics\nOkay, okay, okay\nCountin...           439186.0
# 4                                                     NaN                NaN
# ...                                                   ...                ...
# 156475                                                NaN                NaN
# 156476  What I Want Is What I’ve Got Lyrics\nAll that ...                NaN
# 156477                                                NaN                NaN
# 156478  Can’t Lose What You Never Had Lyrics\nBaby you...             6644.0
# 156479  My Private Movie LyricsPretty girls are all ar...                NaN
#
#        track_number           album_name  album_artist  album_release_date  \
# 0                 1  Certified Lover Boy         Drake          2021-09-03
# 1                 2  Certified Lover Boy         Drake          2021-09-03
# 2                 3  Certified Lover Boy         Drake          2021-09-03
# 3                 4  Certified Lover Boy         Drake          2021-09-03
# 4                 5  Certified Lover Boy         Drake          2021-09-03
# ...             ...                  ...           ...                 ...
# 156475           14             Westlife      Westlife          1999-11-01
# 156476           15             Westlife      Westlife          1999-11-01
# 156477           16             Westlife      Westlife          1999-11-01
# 156478           17             Westlife      Westlife          1999-11-01
# 156479           18             Westlife      Westlife          1999-11-01
#
#         album_popularity  album_record_label  \
# 0                     95                 OVO
# 1                     95                 OVO
# 2                     95                 OVO
# 3                     95                 OVO
# 4                     95                 OVO
# ...                  ...                 ...
# 156475                73   RCA Records Label
# 156476                73   RCA Records Label
# 156477                73   RCA Records Label
# 156478                73   RCA Records Label
# 156479                73   RCA Records Label
#
#                                               album_cover
# 0       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 1       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 2       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 3       https://i.scdn.co/image/ab67616d00001e02cd945b...
# 4       https://i.scdn.co/image/ab67616d00001e02cd945b...
# ...                                                   ...
# 156475  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 156476  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 156477  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 156478  https://i.scdn.co/image/ab67616d00001e0244ead2...
# 156479  https://i.scdn.co/image/ab67616d00001e0244ead2...
#
# [156480 rows x 31 columns]

# %%
df.nunique()
# Out:
# track_uri                 156480
# track_name                105118
# cleaned_track_name         57046
# track_artists              17885
# featured_artists            5782
# track_is_explicit              2
# track_popularity              98
# track_genres                2867
# track_duration_ms          53780
# track_time_signature           5
# track_acousticness          4155
# track_danceability          1151
# track_energy                1896
# track_key_signature           24
# track_instrumentalness      5290
# track_key                     12
# track_mode                     2
# track_liveness              1668
# track_loudness             18413
# track_speechiness           1594
# track_tempo                44004
# track_valence               1650
# track_lyrics               57956
# lyrics_page_views          25974
# track_number                  50
# album_name                  9574
# album_artist                 797
# album_release_date          3771
# album_popularity             100
# album_record_label          1448
# album_cover                 9752
# dtype: int64

# %%
describ = df.describe() # assign describe to variable
null_sum = pd.concat([df.isnull().sum().rename('NullData'),describ.T],axis=1)
null_sum
# Out:
#                         NullData     count           mean            std  \
# track_uri                      0       NaN            NaN            NaN
# track_name                     0       NaN            NaN            NaN
# cleaned_track_name         66990       NaN            NaN            NaN
# track_artists                  0       NaN            NaN            NaN
# featured_artists          141659       NaN            NaN            NaN
# track_is_explicit              0       NaN            NaN            NaN
# track_popularity               0  156480.0      29.935493      19.590452
# track_genres                   0       NaN            NaN            NaN
# track_duration_ms              0  156480.0  227073.490523  109823.237372
# track_time_signature          48  156432.0       3.900672       0.448843
# track_acousticness            48  156432.0       0.318634       0.318640
# track_danceability            48  156432.0       0.565730       0.179148
# track_energy                  48  156432.0       0.599987       0.236343
# track_key_signature           48       NaN            NaN            NaN
# track_instrumentalness        48  156432.0       0.081066       0.231373
# track_key                     48  156432.0       5.205923       3.573902
# track_mode                    48  156432.0       0.658094       0.474350
# track_liveness                48  156432.0       0.257520       0.246347
# track_loudness                48  156432.0      -8.473155       4.581640
# track_speechiness             48  156432.0       0.114200       0.143928
# track_tempo                   48  156432.0     120.037396      30.347297
# track_valence                 48  156432.0       0.473915       0.246602
# track_lyrics               72209       NaN            NaN            NaN
# lyrics_page_views         111908   44572.0  175114.766176  543363.924921
# track_number                   0  156480.0       8.921115       6.531437
# album_name                     0       NaN            NaN            NaN
# album_artist                   0       NaN            NaN            NaN
# album_release_date             0       NaN            NaN            NaN
# album_popularity               0  156480.0      46.818852      20.960460
# album_record_label             0       NaN            NaN            NaN
# album_cover                   41       NaN            NaN            NaN
#
#                            min          25%            50%           75%  \
# track_uri                  NaN          NaN            NaN           NaN
# track_name                 NaN          NaN            NaN           NaN
# cleaned_track_name         NaN          NaN            NaN           NaN
# track_artists              NaN          NaN            NaN           NaN
# featured_artists           NaN          NaN            NaN           NaN
# track_is_explicit          NaN          NaN            NaN           NaN
# track_popularity           0.0      14.0000      29.000000      44.00000
# track_genres               NaN          NaN            NaN           NaN
# track_duration_ms       3338.0  177413.0000  214706.000000  259733.00000
# track_time_signature       0.0       4.0000       4.000000       4.00000
# track_acousticness         0.0       0.0375       0.192000       0.57700
# track_danceability         0.0       0.4470       0.581000       0.70000
# track_energy               0.0       0.4420       0.632000       0.78800
# track_key_signature        NaN          NaN            NaN           NaN
# track_instrumentalness     0.0       0.0000       0.000003       0.00123
# track_key                  0.0       2.0000       5.000000       8.00000
# track_mode                 0.0       0.0000       1.000000       1.00000
# track_liveness             0.0       0.1010       0.143000       0.31900
# track_loudness           -60.0     -10.2430      -7.289000      -5.40700
# track_speechiness          0.0       0.0362       0.052400       0.12400
# track_tempo                0.0      95.3720     119.985500     139.95100
# track_valence              0.0       0.2780       0.465000       0.66300
# track_lyrics               NaN          NaN            NaN           NaN
# lyrics_page_views       5001.0   13837.0000   38607.000000  132539.75000
# track_number               1.0       4.0000       8.000000      12.00000
# album_name                 NaN          NaN            NaN           NaN
# album_artist               NaN          NaN            NaN           NaN
# album_release_date         NaN          NaN            NaN           NaN
# album_popularity           0.0      32.0000      48.000000      63.00000
# album_record_label         NaN          NaN            NaN           NaN
# album_cover                NaN          NaN            NaN           NaN
#
#                                  max
# track_uri                        NaN
# track_name                       NaN
# cleaned_track_name               NaN
# track_artists                    NaN
# featured_artists                 NaN
# track_is_explicit                NaN
# track_popularity        9.700000e+01
# track_genres                     NaN
# track_duration_ms       4.794398e+06
# track_time_signature    5.000000e+00
# track_acousticness      9.960000e-01
# track_danceability      9.800000e-01
# track_energy            1.000000e+00
# track_key_signature              NaN
# track_instrumentalness  1.000000e+00
# track_key               1.100000e+01
# track_mode              1.000000e+00
# track_liveness          1.000000e+00
# track_loudness          9.320000e-01
# track_speechiness       9.660000e-01
# track_tempo             2.410050e+02
# track_valence           1.000000e+00
# track_lyrics                     NaN
# lyrics_page_views       2.335146e+07
# track_number            5.000000e+01
# album_name                       NaN
# album_artist                     NaN
# album_release_date               NaN
# album_popularity        1.000000e+02
# album_record_label               NaN
# album_cover                      NaN

# %% [markdown]
# ##### Removing Non-Lyrics
#
# The Genius API sometimes returns discographies or interviews for unreleased or unavailable lyrics instead of returning the lyrics for the specific song. Thus to make the analysis as accurate as possible, it is important to remove any data that was retrieved from the Genius API that takes that format. In order to begin this process, the track_lyrics column is checked for the words "unreleased, Unreleased, Discography, discography" which tracks of this format usually have in common. This is done using the contains function. The na value is set to false to only get the tracks that meet the condition specified.

# %%
contain_values = df[df['track_lyrics'].str.contains('unreleased|Unreleased|Discography|discography', na=False)]
contain_values[['cleaned_track_name','track_lyrics']]
# Out:
#                          cleaned_track_name  \
# 237                       Drake Discography
# 298     Unreleased Songs [Discography List]
# 952     Unreleased Songs [Discography List]
# 977     Unreleased Songs [Discography List]
# 1572                Eminem Discography List
# ...                                     ...
# 123466  Unreleased Songs [Discography List]
# 142033  Unreleased Songs [Discography List]
# 150197  Unreleased Songs [Discography List]
# 150236  Unreleased Songs [Discography List]
# 150238  Unreleased Songs [Discography List]
#
#                                              track_lyrics
# 237     Drake Discography LyricsProjects:2006:• Room f...
# 298     Unreleased Songs  Lyrics2007Grow Back2008Fuldh...
# 952     Unreleased Songs  LyricsBy Year:20072008200920...
# 977     Unreleased Songs  LyricsBy Year:20072008200920...
# 1572    Eminem Discography List LyricsProjects:1996:• ...
# ...                                                   ...
# 123466  Unreleased Songs  Lyrics1998Give Unto Me (Evan...
# 142033  Unreleased Songs  Lyrics2005Don't Lie (No No N...
# 150197  Unreleased Songs  Lyrics2004Ahh! (Goodies outt...
# 150236  Unreleased Songs  Lyrics2004Ahh! (Goodies outt...
# 150238  Unreleased Songs  Lyrics2004Ahh! (Goodies outt...
#
# [158 rows x 2 columns]

# %% [markdown]
# After taking a closer look at the 158 rows returned, it is noticed that 13 tracks actually contained the word discography as a lyric so in order to ensure these tracks don't get removed from the dataframe. Therefore, the cleaned_track_name column is considered as almost all tracks share the substring "Discography" with some exceptions which are taken into account below.

# %%
values = df[df['cleaned_track_name'].str.contains('Anniversary Box Set|Discography|Cherry Bomb: The Documentary|The History of Iron Maiden - Part 1: The Early Days', na=False)]
values[['cleaned_track_name','track_lyrics']]
# Out:
#                          cleaned_track_name  \
# 237                       Drake Discography
# 298     Unreleased Songs [Discography List]
# 952     Unreleased Songs [Discography List]
# 977     Unreleased Songs [Discography List]
# 1572                Eminem Discography List
# ...                                     ...
# 123466  Unreleased Songs [Discography List]
# 142033  Unreleased Songs [Discography List]
# 150197  Unreleased Songs [Discography List]
# 150236  Unreleased Songs [Discography List]
# 150238  Unreleased Songs [Discography List]
#
#                                              track_lyrics
# 237     Drake Discography LyricsProjects:2006:• Room f...
# 298     Unreleased Songs  Lyrics2007Grow Back2008Fuldh...
# 952     Unreleased Songs  LyricsBy Year:20072008200920...
# 977     Unreleased Songs  LyricsBy Year:20072008200920...
# 1572    Eminem Discography List LyricsProjects:1996:• ...
# ...                                                   ...
# 123466  Unreleased Songs  Lyrics1998Give Unto Me (Evan...
# 142033  Unreleased Songs  Lyrics2005Don't Lie (No No N...
# 150197  Unreleased Songs  Lyrics2004Ahh! (Goodies outt...
# 150236  Unreleased Songs  Lyrics2004Ahh! (Goodies outt...
# 150238  Unreleased Songs  Lyrics2004Ahh! (Goodies outt...
#
# [145 rows x 2 columns]

# %% [markdown]
# The rows returned after applying the conditions discussed above on the cleaned_track_name are all true non-lyric data which can safely be replaced with np.nan values in the dataframe.

# %%
df.loc[df['cleaned_track_name'].str.contains('Anniversary Box Set|Discography|Cherry Bomb: The Documentary|The History of Iron Maiden - Part 1: The Early Days', na=False), ['cleaned_track_name', 'featured_artists', 'track_lyrics', 'lyrics_page_views']] = np.nan

# vals where successfully removed
#vals = df[df['cleaned_track_name'].str.contains('Anniversary Box Set|Discography|Cherry Bomb: The Documentary|The History of Iron Maiden - Part 1: The Early Days', na=False)]

# %% [markdown]
# Now, the null values can be displayed again to ensure successful removal. The values for 'cleaned_track_name', 'featured_artists', 'track_lyrics', and 'lyrics_page_views' went from 66990, 141659, 72209, and 111908 to 67135, 141659, 72354, and 111929 respectively indicating a change in the null data in these columns and a successful application of the replacement function.

# %%
describ = df.describe() # assign describe to variable
null_sum = pd.concat([df.isnull().sum().rename('NullData'),describ.T],axis=1)
null_sum
# Out:
#                         NullData     count           mean            std  \
# track_uri                      0       NaN            NaN            NaN
# track_name                     0       NaN            NaN            NaN
# cleaned_track_name         67135       NaN            NaN            NaN
# track_artists                  0       NaN            NaN            NaN
# featured_artists          141659       NaN            NaN            NaN
# track_is_explicit              0       NaN            NaN            NaN
# track_popularity               0  156480.0      29.935493      19.590452
# track_genres                   0       NaN            NaN            NaN
# track_duration_ms              0  156480.0  227073.490523  109823.237372
# track_time_signature          48  156432.0       3.900672       0.448843
# track_acousticness            48  156432.0       0.318634       0.318640
# track_danceability            48  156432.0       0.565730       0.179148
# track_energy                  48  156432.0       0.599987       0.236343
# track_key_signature           48       NaN            NaN            NaN
# track_instrumentalness        48  156432.0       0.081066       0.231373
# track_key                     48  156432.0       5.205923       3.573902
# track_mode                    48  156432.0       0.658094       0.474350
# track_liveness                48  156432.0       0.257520       0.246347
# track_loudness                48  156432.0      -8.473155       4.581640
# track_speechiness             48  156432.0       0.114200       0.143928
# track_tempo                   48  156432.0     120.037396      30.347297
# track_valence                 48  156432.0       0.473915       0.246602
# track_lyrics               72354       NaN            NaN            NaN
# lyrics_page_views         111929   44551.0  175191.433615  543480.445340
# track_number                   0  156480.0       8.921115       6.531437
# album_name                     0       NaN            NaN            NaN
# album_artist                   0       NaN            NaN            NaN
# album_release_date             0       NaN            NaN            NaN
# album_popularity               0  156480.0      46.818852      20.960460
# album_record_label             0       NaN            NaN            NaN
# album_cover                   41       NaN            NaN            NaN
#
#                            min          25%            50%           75%  \
# track_uri                  NaN          NaN            NaN           NaN
# track_name                 NaN          NaN            NaN           NaN
# cleaned_track_name         NaN          NaN            NaN           NaN
# track_artists              NaN          NaN            NaN           NaN
# featured_artists           NaN          NaN            NaN           NaN
# track_is_explicit          NaN          NaN            NaN           NaN
# track_popularity           0.0      14.0000      29.000000      44.00000
# track_genres               NaN          NaN            NaN           NaN
# track_duration_ms       3338.0  177413.0000  214706.000000  259733.00000
# track_time_signature       0.0       4.0000       4.000000       4.00000
# track_acousticness         0.0       0.0375       0.192000       0.57700
# track_danceability         0.0       0.4470       0.581000       0.70000
# track_energy               0.0       0.4420       0.632000       0.78800
# track_key_signature        NaN          NaN            NaN           NaN
# track_instrumentalness     0.0       0.0000       0.000003       0.00123
# track_key                  0.0       2.0000       5.000000       8.00000
# track_mode                 0.0       0.0000       1.000000       1.00000
# track_liveness             0.0       0.1010       0.143000       0.31900
# track_loudness           -60.0     -10.2430      -7.289000      -5.40700
# track_speechiness          0.0       0.0362       0.052400       0.12400
# track_tempo                0.0      95.3720     119.985500     139.95100
# track_valence              0.0       0.2780       0.465000       0.66300
# track_lyrics               NaN          NaN            NaN           NaN
# lyrics_page_views       5001.0   13852.0000   38647.000000  132551.00000
# track_number               1.0       4.0000       8.000000      12.00000
# album_name                 NaN          NaN            NaN           NaN
# album_artist               NaN          NaN            NaN           NaN
# album_release_date         NaN          NaN            NaN           NaN
# album_popularity           0.0      32.0000      48.000000      63.00000
# album_record_label         NaN          NaN            NaN           NaN
# album_cover                NaN          NaN            NaN           NaN
#
#                                  max
# track_uri                        NaN
# track_name                       NaN
# cleaned_track_name               NaN
# track_artists                    NaN
# featured_artists                 NaN
# track_is_explicit                NaN
# track_popularity        9.700000e+01
# track_genres                     NaN
# track_duration_ms       4.794398e+06
# track_time_signature    5.000000e+00
# track_acousticness      9.960000e-01
# track_danceability      9.800000e-01
# track_energy            1.000000e+00
# track_key_signature              NaN
# track_instrumentalness  1.000000e+00
# track_key               1.100000e+01
# track_mode              1.000000e+00
# track_liveness          1.000000e+00
# track_loudness          9.320000e-01
# track_speechiness       9.660000e-01
# track_tempo             2.410050e+02
# track_valence           1.000000e+00
# track_lyrics                     NaN
# lyrics_page_views       2.335146e+07
# track_number            5.000000e+01
# album_name                       NaN
# album_artist                     NaN
# album_release_date               NaN
# album_popularity        1.000000e+02
# album_record_label               NaN
# album_cover                      NaN

# %% [markdown]
# After further research and examination of the dataframe, it was identified that the Genius API also returned some charts, playlists, tracklists, interviews, track credits and radio episodes instead of returning lyrics for some of the songs. The patterns that appeared in the lyrics were identified and used to retrieve song lyrics that contained any of the mentioned patterns using str.contains.

# %%
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')

non_lyrics = df[df['track_lyrics'].str.contains('Tracklist|Radio Episode|Chart History|Billboard 200 Charts|Macklemore|Track List Lyrics|Music Videos Lyrics|Playlist Lyrics|Exclusive Playlist|Interview|23:55 Lyrics|HILLSONG UNITEDEmbed|Stones for a Thousand Years LyricsEmbed|A State Of Trance  - A State of Trance Year Mix 2014|In Rhythm LyricsEmbed|The Adventures of Bobby Ray  Lyrics|Fingertips, part 2 - live at the regal theater/1963/ single version', na=False)]
non_lyrics[['cleaned_track_name','track_lyrics']]
# Out:
#                                       cleaned_track_name  \
# 54                  OVO Sound Radio Episode 62 Tracklist
# 63                  OVO Sound Radio Episode 11 Tracklist
# 92                  OVO Sound Radio Episode 65 Tracklist
# 209                         HYFR (Hell Ya Fucking Right)
# 228                         HYFR (Hell Ya Fucking Right)
# ...                                                  ...
# 143218  Bang 3 (Part 1 & Part 2) [Album Art + Tracklist]
# 143230  Bang 3 (Part 1 & Part 2) [Album Art + Tracklist]
# 152185                                 Rockin’ In Rhythm
# 153002                                 Rockin’ In Rhythm
# 153863                                 Rockin’ In Rhythm
#
#                                              track_lyrics
# 54      OVO Sound Radio Episode 62 Tracklist LyricsOli...
# 63      OVO Sound Radio Episode 11 Tracklist LyricsILo...
# 92      OVO Sound Radio Episode 65 Tracklist LyricsOct...
# 209     HYFR (Hell Ya Fucking Right) Lyrics\nGotta do ...
# 228     HYFR (Hell Ya Fucking Right) Lyrics\nGotta do ...
# ...                                                   ...
# 143218  Bang 3 (Part 1 & Part 2)  LyricsPart 1Tracklis...
# 143230  Bang 3 (Part 1 & Part 2)  LyricsPart 1Tracklis...
# 152185                      Rockin’ In Rhythm LyricsEmbed
# 153002                      Rockin’ In Rhythm LyricsEmbed
# 153863                      Rockin’ In Rhythm LyricsEmbed
#
# [233 rows x 2 columns]

# %% [markdown]
# After taking a closer look at the 233 rows returned, it is identified that using the lyrics patterns is not ideal as there are some actual song lyrics containing the pattern above. Rather, it is a better approach to use the cleaned_track_name to avoid removing lyrics. There were common patterns identified for the cleaned_track_name of the non-lyrics data with substrings such as \[Credits\], Tracklists, Music  Videos and some others as shown below.

# %%
non_lyrics_check = df[df['cleaned_track_name'].str.contains('OVO Sound Radio Episode|Chart History| Tracklist| Music Videos|The Singles Collection Tracklist| - Album Art| Track List| Album Art| Album Art/Tracklist|Hnscc| Album Cover| \[Tracklist + Album Cover\]|Yup (Bath Time Playlist)|The motherfucking future Playlist|Liam Payne: Exclusive Playlist|Evening Standard Magazine| Billboard Interview|23:55|Entertainment Weekly Interview|A State Of Trance \[ASOT 692\] - A State of Trance Year Mix 2014|Interview - 107.7 The End - Blue vs. Pinkerton|There Is Nothing Like| \[Tracklist & Artwork\]|Fingertips, part 2 - live at the regal theater/1963/ single version|Stones for a Thousand Years| \[Credits\]| \[Tracklist + Album Art\]| Album Art + Tracklist| \[Tracklist + Cover Art\]| In Rhythm', na=False)]
non_lyrics_check[['cleaned_track_name','track_lyrics']]
# Out:
#                                       cleaned_track_name  \
# 54                  OVO Sound Radio Episode 62 Tracklist
# 63                  OVO Sound Radio Episode 11 Tracklist
# 92                  OVO Sound Radio Episode 65 Tracklist
# 345                           Ed Sheeran’s Chart History
# 684                        MEMENTO MORI Ep. 16 Tracklist
# ...                                                  ...
# 143218  Bang 3 (Part 1 & Part 2) [Album Art + Tracklist]
# 143230  Bang 3 (Part 1 & Part 2) [Album Art + Tracklist]
# 152185                                 Rockin’ In Rhythm
# 153002                                 Rockin’ In Rhythm
# 153863                                 Rockin’ In Rhythm
#
#                                              track_lyrics
# 54      OVO Sound Radio Episode 62 Tracklist LyricsOli...
# 63      OVO Sound Radio Episode 11 Tracklist LyricsILo...
# 92      OVO Sound Radio Episode 65 Tracklist LyricsOct...
# 345     Ed Sheeran’s Chart History LyricsAlbums & EPs ...
# 684     MEMENTO MORI Ep. 16 Tracklist LyricsThe Weeknd...
# ...                                                   ...
# 143218  Bang 3 (Part 1 & Part 2)  LyricsPart 1Tracklis...
# 143230  Bang 3 (Part 1 & Part 2)  LyricsPart 1Tracklis...
# 152185                      Rockin’ In Rhythm LyricsEmbed
# 153002                      Rockin’ In Rhythm LyricsEmbed
# 153863                      Rockin’ In Rhythm LyricsEmbed
#
# [233 rows x 2 columns]

# %% [markdown]
# The result from rows returned using the cleaned_track_name non-lyrics patterns are all true non-lyrics data which can be safely replaced with np.nan values in the dataframe.

# %%
df.loc[df['cleaned_track_name'].str.contains('OVO Sound Radio Episode|Chart History| Tracklist| Music Videos|The Singles Collection Tracklist| - Album Art| Track List| Album Art| Album Art/Tracklist|Hnscc| Album Cover| \[Tracklist + Album Cover\]|Yup (Bath Time Playlist)|The motherfucking future Playlist|Liam Payne: Exclusive Playlist|Evening Standard Magazine| Billboard Interview|23:55|Entertainment Weekly Interview|A State Of Trance \[ASOT 692\] - A State of Trance Year Mix 2014|Interview - 107.7 The End - Blue vs. Pinkerton|There Is Nothing Like| \[Tracklist & Artwork\]|Fingertips, part 2 - live at the regal theater/1963/ single version|Stones for a Thousand Years| \[Credits\]| \[Tracklist + Album Art\]| Album Art + Tracklist| \[Tracklist + Cover Art\]| In Rhythm', na=False), ['cleaned_track_name', 'featured_artists', 'track_lyrics', 'lyrics_page_views']] = np.nan

# %% [markdown]
# Now, the null values can be displayed again to ensure successful removal. The values for 'cleaned_track_name', 'featured_artists', 'track_lyrics', and 'lyrics_page_views' went from 67135, 141659, 72354, and 111929 to 67368, 141661, 72587, and 111993 respectively indicating a change in the null data in these columns and a successful application of the replacement function.

# %%
describ = df.describe() # assign describe to variable
null_sum = pd.concat([df.isnull().sum().rename('NullData'),describ.T],axis=1)
null_sum
# Out:
#                         NullData     count           mean            std  \
# track_uri                      0       NaN            NaN            NaN
# track_name                     0       NaN            NaN            NaN
# cleaned_track_name         67368       NaN            NaN            NaN
# track_artists                  0       NaN            NaN            NaN
# featured_artists          141661       NaN            NaN            NaN
# track_is_explicit              0       NaN            NaN            NaN
# track_popularity               0  156480.0      29.935493      19.590452
# track_genres                   0       NaN            NaN            NaN
# track_duration_ms              0  156480.0  227073.490523  109823.237372
# track_time_signature          48  156432.0       3.900672       0.448843
# track_acousticness            48  156432.0       0.318634       0.318640
# track_danceability            48  156432.0       0.565730       0.179148
# track_energy                  48  156432.0       0.599987       0.236343
# track_key_signature           48       NaN            NaN            NaN
# track_instrumentalness        48  156432.0       0.081066       0.231373
# track_key                     48  156432.0       5.205923       3.573902
# track_mode                    48  156432.0       0.658094       0.474350
# track_liveness                48  156432.0       0.257520       0.246347
# track_loudness                48  156432.0      -8.473155       4.581640
# track_speechiness             48  156432.0       0.114200       0.143928
# track_tempo                   48  156432.0     120.037396      30.347297
# track_valence                 48  156432.0       0.473915       0.246602
# track_lyrics               72587       NaN            NaN            NaN
# lyrics_page_views         111993   44487.0  175421.732619  543837.149877
# track_number                   0  156480.0       8.921115       6.531437
# album_name                     0       NaN            NaN            NaN
# album_artist                   0       NaN            NaN            NaN
# album_release_date             0       NaN            NaN            NaN
# album_popularity               0  156480.0      46.818852      20.960460
# album_record_label             0       NaN            NaN            NaN
# album_cover                   41       NaN            NaN            NaN
#
#                            min          25%            50%           75%  \
# track_uri                  NaN          NaN            NaN           NaN
# track_name                 NaN          NaN            NaN           NaN
# cleaned_track_name         NaN          NaN            NaN           NaN
# track_artists              NaN          NaN            NaN           NaN
# featured_artists           NaN          NaN            NaN           NaN
# track_is_explicit          NaN          NaN            NaN           NaN
# track_popularity           0.0      14.0000      29.000000      44.00000
# track_genres               NaN          NaN            NaN           NaN
# track_duration_ms       3338.0  177413.0000  214706.000000  259733.00000
# track_time_signature       0.0       4.0000       4.000000       4.00000
# track_acousticness         0.0       0.0375       0.192000       0.57700
# track_danceability         0.0       0.4470       0.581000       0.70000
# track_energy               0.0       0.4420       0.632000       0.78800
# track_key_signature        NaN          NaN            NaN           NaN
# track_instrumentalness     0.0       0.0000       0.000003       0.00123
# track_key                  0.0       2.0000       5.000000       8.00000
# track_mode                 0.0       0.0000       1.000000       1.00000
# track_liveness             0.0       0.1010       0.143000       0.31900
# track_loudness           -60.0     -10.2430      -7.289000      -5.40700
# track_speechiness          0.0       0.0362       0.052400       0.12400
# track_tempo                0.0      95.3720     119.985500     139.95100
# track_valence              0.0       0.2780       0.465000       0.66300
# track_lyrics               NaN          NaN            NaN           NaN
# lyrics_page_views       5001.0   13874.0000   38758.000000  132955.00000
# track_number               1.0       4.0000       8.000000      12.00000
# album_name                 NaN          NaN            NaN           NaN
# album_artist               NaN          NaN            NaN           NaN
# album_release_date         NaN          NaN            NaN           NaN
# album_popularity           0.0      32.0000      48.000000      63.00000
# album_record_label         NaN          NaN            NaN           NaN
# album_cover                NaN          NaN            NaN           NaN
#
#                                  max
# track_uri                        NaN
# track_name                       NaN
# cleaned_track_name               NaN
# track_artists                    NaN
# featured_artists                 NaN
# track_is_explicit                NaN
# track_popularity        9.700000e+01
# track_genres                     NaN
# track_duration_ms       4.794398e+06
# track_time_signature    5.000000e+00
# track_acousticness      9.960000e-01
# track_danceability      9.800000e-01
# track_energy            1.000000e+00
# track_key_signature              NaN
# track_instrumentalness  1.000000e+00
# track_key               1.100000e+01
# track_mode              1.000000e+00
# track_liveness          1.000000e+00
# track_loudness          9.320000e-01
# track_speechiness       9.660000e-01
# track_tempo             2.410050e+02
# track_valence           1.000000e+00
# track_lyrics                     NaN
# lyrics_page_views       2.335146e+07
# track_number            5.000000e+01
# album_name                       NaN
# album_artist                     NaN
# album_release_date               NaN
# album_popularity        1.000000e+02
# album_record_label               NaN
# album_cover                      NaN

# %% [markdown]
# The following functions are used to check that how many tracks were instrumental from the null data collected.

# %%
instrumental_lyrics = df[(df['track_name'].str.contains('Instrumental|instrumental', na=False)) & (df['track_lyrics'].isnull())]
instrumental_lyrics[['track_name','track_lyrics']]
# Out:
#                                                track_name track_lyrics
# 1568                   The Real Slim Shady - Instrumental          NaN
# 1569                          The Way I Am - Instrumental          NaN
# 1616                     Guilty Conscience - Instrumental          NaN
# 1618                            My Name Is - Instrumental          NaN
# 1620                Just Don't Give A Fuck - Instrumental          NaN
# ...                                                   ...          ...
# 155173  If I Could Be With You (One Hour Tonight) - In...          NaN
# 155174  I Hear Music - Instrumental; 1993 Digital Rema...          NaN
# 155175   Tea For Two - Instrumental;1993 Digital Remaster          NaN
# 155226     What Is This Thing Called Love? - Instrumental          NaN
# 156255                              Fundão - Instrumental          NaN
#
# [1275 rows x 2 columns]

# %% [markdown]
# The cleaned dataframe is exported to be stored on hadoop.

# %%
df.to_csv('all_tracks_hadoop.csv', index=False, header=False)
